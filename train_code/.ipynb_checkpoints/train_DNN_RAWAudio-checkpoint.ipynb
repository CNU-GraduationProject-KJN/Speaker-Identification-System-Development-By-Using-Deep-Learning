# %% [markdown]
# https://github.com/vivek081166/raw-audio-deep-learning/blob/master/constants.py

# %%
import pickle
from glob import iglob
import numpy as np
import librosa
from shutil import rmtree
from constants import *
# from constants import DATA_AUDIO_DIR

DATA_AUDIO_DIR = '../test_train_data'
list_dir = os.listdir(DATA_AUDIO_DIR)
list_dir.sort()
print(TARGET_SR)
TARGET_SR = 8000


def mkdir_p(path):
    import errno
    try:
        os.makedirs(path)
    except OSError as exc:
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise


# def del_folder(path):
#     try:
#         rmtree(path)
#     except:
#         pass


# del_folder(OUTPUT_DIR_TRAIN)
# del_folder(OUTPUT_DIR_TEST)
mkdir_p(OUTPUT_DIR_TRAIN)
mkdir_p(OUTPUT_DIR_TEST)

order = 0
class_ids = {list_dir[i]: i for i in range(len(list_dir))}


def extract_class_id(wav_filename):
#     print(class_ids.get(str(wav_filename[18:-6])))
    return class_ids.get(wav_filename[19:-6])


def read_audio_from_filename(filename, target_sr):
    audio, _ = librosa.load(filename, sr=target_sr, mono=True)
    audio = audio.reshape(-1, 1)
    return audio


def convert_data():
    DATA_AUDIO_DIR = '../test_train_data'
    list_dir = os.listdir(DATA_AUDIO_DIR)
    list_dir.sort()
#     TARGET_SR = 16000
#     print(list_dir)
#     AUDIO_LENGTH = 200000
    for i, wav_filename in enumerate(iglob(os.path.join(DATA_AUDIO_DIR, '**/**.wav'), recursive=True)):
#         print(i, wav_filename)
        class_id = extract_class_id(wav_filename)
        audio_buf = read_audio_from_filename(wav_filename, target_sr=TARGET_SR)
        # normalize mean 0, variance 1
        audio_buf = (audio_buf - np.mean(audio_buf)) / np.std(audio_buf)
        original_length = len(audio_buf)
        print(i, wav_filename, original_length, np.round(np.mean(audio_buf), 4), np.std(audio_buf))
        if original_length < AUDIO_LENGTH:
            audio_buf = np.concatenate((audio_buf, np.zeros(shape=(AUDIO_LENGTH - original_length, 1))))
            print('PAD New length =', len(audio_buf))
        elif original_length > AUDIO_LENGTH:
#             audio_buf = audio_buf[10000:AUDIO_LENGTH+10000]
            audio_buf = audio_buf[0:AUDIO_LENGTH]
            print('CUT New length =', len(audio_buf))

        output_folder = OUTPUT_DIR_TRAIN
#         print("wav_filename_end : ", wav_filename[-5:])
        if wav_filename[-5:] == '5.wav':
            output_folder = OUTPUT_DIR_TEST

        output_filename = os.path.join(output_folder, str(wav_filename[19:-4]).replace('/', '_') + '.pkl')
#         TARGET_SR = 16000
        out = {'class_id': class_id,
               'audio': audio_buf,
               'sr': TARGET_SR}
        print("-----------------")
        print(out)
        with open(output_filename, 'wb') as w:
            pickle.dump(out, w)


if __name__ == '__main__':
    convert_data()
# Out:
# 8000
# 0 ../test_train_data/2017019770040_kimdajeong/5.wav 206848 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 70, 'audio': array([[ 0.00013852],
#        [ 0.00013852],
#        [ 0.00013852],
#        ...,
#        [-0.02980895],
#        [-0.03729581],
#        [-0.08720826]], dtype=float32), 'sr': 8000}
# 1 ../test_train_data/2017019770040_kimdajeong/4.wav 202752 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 70, 'audio': array([[2.3026911e-05],
#        [2.3026911e-05],
#        [2.3026911e-05],
#        ...,
#        [2.3360132e-01],
#        [6.1935350e-02],
#        [8.8670217e-02]], dtype=float32), 'sr': 8000}
# 2 ../test_train_data/2017019770040_kimdajeong/3.wav 212992 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 70, 'audio': array([[ 1.7347849e-05],
#        [ 1.7347849e-05],
#        [ 1.7347849e-05],
#        ...,
#        [-4.3108135e-01],
#        [-5.9977216e-01],
#        [-8.5968095e-01]], dtype=float32), 'sr': 8000}
# 3 ../test_train_data/2017019770040_kimdajeong/2.wav 222208 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 70, 'audio': array([[-3.4534351e-05],
#        [-3.4534351e-05],
#        [-3.4534351e-05],
#        ...,
#        [ 4.2453066e-02],
#        [ 4.6564773e-02],
#        [ 3.8341362e-02]], dtype=float32), 'sr': 8000}
# 4 ../test_train_data/2017019770040_kimdajeong/1.wav 236544 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 70, 'audio': array([[-5.2349969e-05],
#        [-5.2349969e-05],
#        [-5.2349969e-05],
#        ...,
#        [ 5.9022474e-01],
#        [ 5.8512521e-01],
#        [ 1.5293525e-01]], dtype=float32), 'sr': 8000}
# 5 ../test_train_data/2017019770018_janggyeoul/5.wav 201654 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 48, 'audio': array([[0.00969135],
#        [0.02045201],
#        [0.02778158],
#        ...,
#        [0.12899403],
#        [0.10701635],
#        [0.08528168]], dtype=float32), 'sr': 8000}
# 6 ../test_train_data/2017019770018_janggyeoul/4.wav 190208 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 48, 'audio': array([[ 0.01368058],
#        [-0.00645776],
#        [-0.00721352],
#        ...,
#        [ 0.0139332 ],
#        [ 0.0017182 ],
#        [-0.0048426 ]], dtype=float32), 'sr': 8000}
# 7 ../test_train_data/2017019770018_janggyeoul/3.wav 198006 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 48, 'audio': array([[-0.01071693],
#        [-0.01399099],
#        [-0.00808737],
#        ...,
#        [ 0.17988406],
#        [ 0.07627425],
#        [ 0.037128  ]], dtype=float32), 'sr': 8000}
# 8 ../test_train_data/2017019770018_janggyeoul/2.wav 206448 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 48, 'audio': array([[-0.00461743],
#        [-0.00911326],
#        [ 0.00440984],
#        ...,
#        [-1.647918  ],
#        [-2.198408  ],
#        [-2.6308017 ]], dtype=float32), 'sr': 8000}
# 9 ../test_train_data/2017019770018_janggyeoul/1.wav 205390 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 48, 'audio': array([[0.0142618 ],
#        [0.02603091],
#        [0.00157895],
#        ...,
#        [0.23446803],
#        [0.52855515],
#        [0.4740316 ]], dtype=float32), 'sr': 8000}
# 10 ../test_train_data/2017019770021_heoyoonjung/5.wav 172757 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 51, 'audio': array([[6.8905583e-06],
#        [6.8905583e-06],
#        [6.8905583e-06],
#        ...,
#        [6.5686338e-02],
#        [8.9603856e-02],
#        [1.7658451e-01]], dtype=float32), 'sr': 8000}
# 11 ../test_train_data/2017019770021_heoyoonjung/4.wav 174800 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 51, 'audio': array([[-2.6381938e-05],
#        [-2.6381938e-05],
#        [-2.6381938e-05],
#        ...,
#        [ 2.6181812e+00],
#        [ 1.8873082e+00],
#        [ 1.3603048e+00]], dtype=float32), 'sr': 8000}
# 12 ../test_train_data/2017019770021_heoyoonjung/3.wav 180187 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 51, 'audio': array([[-1.16662432e-05],
#        [-1.16662432e-05],
#        [-1.16662432e-05],
#        ...,
#        [ 1.40155017e-01],
#        [ 1.24414295e-01],
#        [ 1.09314367e-01]], dtype=float32), 'sr': 8000}
# 13 ../test_train_data/2017019770021_heoyoonjung/2.wav 180745 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 51, 'audio': array([[-7.3529045e-05],
#        [-7.3529045e-05],
#        [-7.3529045e-05],
#        ...,
#        [ 1.6194187e-01],
#        [ 2.1388629e-01],
#        [ 1.3335972e-01]], dtype=float32), 'sr': 8000}
# 14 ../test_train_data/2017019770021_heoyoonjung/1.wav 194119 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 51, 'audio': array([[-3.4702937e-06],
#        [-3.4702937e-06],
#        [-3.4702937e-06],
#        ...,
#        [ 1.0806433e-01],
#        [-6.9769102e-01],
#        [-1.2833875e+00]], dtype=float32), 'sr': 8000}
# 15 ../test_train_data/2017019880008_jangsoojin/5.wav 227556 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 78, 'audio': array([[-2.6042406e-05],
#        [-2.6042406e-05],
#        [-2.6042406e-05],
#        ...,
#        [-4.7645232e-01],
#        [-3.9863095e-01],
#        [-7.3624790e-01]], dtype=float32), 'sr': 8000}
# 16 ../test_train_data/2017019880008_jangsoojin/4.wav 229042 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 78, 'audio': array([[ 1.7462477e-05],
#        [ 1.7462477e-05],
#        [ 1.7462477e-05],
#        ...,
#        [ 1.4678111e+00],
#        [ 7.2197354e-01],
#        [-3.0595303e-01]], dtype=float32), 'sr': 8000}
# 17 ../test_train_data/2017019880008_jangsoojin/3.wav 229599 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 78, 'audio': array([[4.9724986e-06],
#        [4.9724986e-06],
#        [4.9724986e-06],
#        ...,
#        [6.0275203e-01],
#        [1.1639186e+00],
#        [1.5048301e+00]], dtype=float32), 'sr': 8000}
# 18 ../test_train_data/2017019880008_jangsoojin/2.wav 231829 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 78, 'audio': array([[-1.9297646e-05],
#        [-1.9297646e-05],
#        [-1.9297646e-05],
#        ...,
#        [-2.1593685e+00],
#        [-2.2629745e+00],
#        [-2.2289848e+00]], dtype=float32), 'sr': 8000}
# 19 ../test_train_data/2017019880008_jangsoojin/1.wav 235358 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 78, 'audio': array([[-2.8679673e-05],
#        [-2.8679673e-05],
#        [-2.8679673e-05],
#        ...,
#        [ 3.2958002e+00],
#        [ 3.0324922e+00],
#        [ 2.5274963e+00]], dtype=float32), 'sr': 8000}
# 20 ../test_train_data/2017019770005_hyeonsanghyeok/5.wav 191318 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 35, 'audio': array([[ 8.7375418e-05],
#        [ 8.7375418e-05],
#        [ 8.7375418e-05],
#        ...,
#        [-1.3468517e+00],
#        [-1.1972469e+00],
#        [-1.4728200e+00]], dtype=float32), 'sr': 8000}
# 21 ../test_train_data/2017019770005_hyeonsanghyeok/4.wav 199510 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 35, 'audio': array([[8.9476373e-05],
#        [8.9476373e-05],
#        [8.9476373e-05],
#        ...,
#        [3.9780241e-01],
#        [4.2027581e-01],
#        [4.3368456e-01]], dtype=float32), 'sr': 8000}
# 22 ../test_train_data/2017019770005_hyeonsanghyeok/3.wav 194731 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 35, 'audio': array([[-4.8336591e-05],
#        [-4.8336591e-05],
#        [-4.8336591e-05],
#        ...,
#        [ 1.0578922e+00],
#        [ 7.5259709e-01],
#        [ 4.5367602e-01]], dtype=float32), 'sr': 8000}
# 23 ../test_train_data/2017019770005_hyeonsanghyeok/2.wav 201728 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 35, 'audio': array([[ 2.0223690e-05],
#        [ 2.0223690e-05],
#        [ 2.0223690e-05],
#        ...,
#        [-6.1683273e-01],
#        [-5.0033873e-01],
#        [-4.8684627e-01]], dtype=float32), 'sr': 8000}
# 24 ../test_train_data/2017019770005_hyeonsanghyeok/1.wav 198144 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 35, 'audio': array([[ 2.9406001e-05],
#        [ 2.9406001e-05],
#        [ 2.9406001e-05],
#        ...,
#        [-4.9580023e-01],
#        [-9.9870080e-01],
#        [-1.4481878e-01]], dtype=float32), 'sr': 8000}
# 25 ../test_train_data/2017019770029_jueunhong/5.wav 255488 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 59, 'audio': array([[ 3.0204807e-05],
#        [-1.0090771e-04],
#        [ 4.1694110e-04],
#        ...,
#        [ 1.2070021e-02],
#        [ 8.3549572e-03],
#        [-3.3376010e-03]], dtype=float32), 'sr': 8000}
# 26 ../test_train_data/2017019770029_jueunhong/4.wav 259072 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 59, 'audio': array([[ 3.9091692e-06],
#        [ 3.9091692e-06],
#        [ 3.9091692e-06],
#        ...,
#        [-5.8335336e-03],
#        [-1.1695621e-02],
#        [ 3.5695128e-02]], dtype=float32), 'sr': 8000}
# 27 ../test_train_data/2017019770029_jueunhong/3.wav 247638 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 59, 'audio': array([[-0.00010425],
#        [ 0.00010068],
#        [ 0.00057014],
#        ...,
#        [-0.00307375],
#        [-0.01077646],
#        [ 0.01805609]], dtype=float32), 'sr': 8000}
# 28 ../test_train_data/2017019770029_jueunhong/2.wav 241835 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 59, 'audio': array([[-1.1187756e-05],
#        [ 7.6389242e-06],
#        [ 1.3279944e-06],
#        ...,
#        [ 5.2146918e-01],
#        [ 5.4620451e-01],
#        [ 4.5610112e-01]], dtype=float32), 'sr': 8000}
# 29 ../test_train_data/2017019770029_jueunhong/1.wav 259584 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 59, 'audio': array([[ 7.3170527e-06],
#        [ 7.3170527e-06],
#        [ 7.3170527e-06],
#        ...,
#        [-1.1011638e-02],
#        [ 1.3122369e-02],
#        [ 1.8693170e-02]], dtype=float32), 'sr': 8000}
# 30 ../test_train_data/2017019740021_kwakbokyeong/5.wav 330923 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 20, 'audio': array([[ 0.00029719],
#        [ 0.00029719],
#        [ 0.00029719],
#        ...,
#        [ 0.10314012],
#        [-0.01683912],
#        [-0.26363406]], dtype=float32), 'sr': 8000}
# 31 ../test_train_data/2017019740021_kwakbokyeong/4.wav 310443 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 20, 'audio': array([[-1.1484633e-04],
#        [-1.1484633e-04],
#        [-1.1484633e-04],
#        ...,
#        [-3.5360762e-01],
#        [-3.6098692e-01],
#        [-4.0431356e-01]], dtype=float32), 'sr': 8000}
# 32 ../test_train_data/2017019740021_kwakbokyeong/3.wav 310102 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 20, 'audio': array([[-0.00040474],
#        [-0.00040474],
#        [-0.00040474],
#        ...,
#        [ 0.12573405],
#        [ 0.13587153],
#        [ 0.14555202]], dtype=float32), 'sr': 8000}
# 33 ../test_train_data/2017019740021_kwakbokyeong/2.wav 304982 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 20, 'audio': array([[-0.00024216],
#        [-0.00024216],
#        [-0.00024216],
#        ...,
#        [-0.06308597],
#        [-0.0404236 ],
#        [-0.02900009]], dtype=float32), 'sr': 8000}
# 34 ../test_train_data/2017019740021_kwakbokyeong/1.wav 314710 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 20, 'audio': array([[-1.6644390e-04],
#        [-1.6644390e-04],
#        [-1.6644390e-04],
#        ...,
#        [-3.0030486e-01],
#        [-9.9426977e-02],
#        [ 3.5306346e-02]], dtype=float32), 'sr': 8000}
# 35 ../test_train_data/2017019740003_songyejin/5.wav 236032 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 2, 'audio': array([[-5.1765037e-06],
#        [-5.1765037e-06],
#        [-5.1765037e-06],
#        ...,
#        [-1.0423548e+00],
#        [-1.6915581e+00],
#        [-2.1566901e+00]], dtype=float32), 'sr': 8000}
# 36 ../test_train_data/2017019740003_songyejin/4.wav 244736 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 2, 'audio': array([[-1.8383058e-05],
#        [-1.8383058e-05],
#        [-1.8383058e-05],
#        ...,
#        [-4.0512510e-02],
#        [-4.4567060e-02],
#        [-5.3258847e-02]], dtype=float32), 'sr': 8000}
# 37 ../test_train_data/2017019740003_songyejin/3.wav 237056 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 2, 'audio': array([[-8.3280183e-06],
#        [-8.3280183e-06],
#        [-8.3280183e-06],
#        ...,
#        [ 1.4930873e+00],
#        [ 1.5424013e+00],
#        [ 1.4005646e+00]], dtype=float32), 'sr': 8000}
# 38 ../test_train_data/2017019740003_songyejin/2.wav 230912 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 2, 'audio': array([[-2.2376958e-05],
#        [-2.2376958e-05],
#        [-2.2376958e-05],
#        ...,
#        [-2.4442849e+00],
#        [-2.4557297e+00],
#        [-2.4734170e+00]], dtype=float32), 'sr': 8000}
# 39 ../test_train_data/2017019740003_songyejin/1.wav 237568 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 2, 'audio': array([[4.3458058e-05],
#        [4.3458058e-05],
#        [4.3458058e-05],
#        ...,
#        [1.6124891e-01],
#        [5.3040254e-01],
#        [5.9564400e-01]], dtype=float32), 'sr': 8000}
# 40 ../test_train_data/2017019880002_kimkihyeon/5.wav 193562 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 72, 'audio': array([[4.3340904e-05],
#        [4.3340904e-05],
#        [4.3340904e-05],
#        ...,
#        [2.7781148e-02],
#        [3.1785775e-02],
#        [2.9035902e-02]], dtype=float32), 'sr': 8000}
# 41 ../test_train_data/2017019880002_kimkihyeon/4.wav 220126 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 72, 'audio': array([[-1.3648794e-04],
#        [-1.3648794e-04],
#        [-1.3648794e-04],
#        ...,
#        [ 3.0839407e-01],
#        [ 3.4784889e-01],
#        [ 3.6799717e-01]], dtype=float32), 'sr': 8000}
# 42 ../test_train_data/2017019880002_kimkihyeon/3.wav 211023 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 72, 'audio': array([[3.3679604e-05],
#        [3.3679604e-05],
#        [3.3679604e-05],
#        ...,
#        [1.8420875e+00],
#        [2.1685159e+00],
#        [2.3836710e+00]], dtype=float32), 'sr': 8000}
# 43 ../test_train_data/2017019880002_kimkihyeon/2.wav 236287 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 72, 'audio': array([[-0.00011608],
#        [-0.00011608],
#        [-0.00011608],
#        ...,
#        [ 0.03140057],
#        [ 0.02869307],
#        [ 0.02775986]], dtype=float32), 'sr': 8000}
# 44 ../test_train_data/2017019880002_kimkihyeon/1.wav 282727 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 72, 'audio': array([[-0.0001078 ],
#        [-0.0001078 ],
#        [-0.0001078 ],
#        ...,
#        [-0.01705954],
#        [-0.01539347],
#        [-0.01211454]], dtype=float32), 'sr': 8000}
# 45 ../test_train_data/2017019880017_sungsoohyun/5.wav 236715 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 87, 'audio': array([[-1.1975970e-04],
#        [-1.1975970e-04],
#        [-1.1975970e-04],
#        ...,
#        [-1.8402340e+00],
#        [-1.6488661e+00],
#        [-1.4864079e+00]], dtype=float32), 'sr': 8000}
# 46 ../test_train_data/2017019880017_sungsoohyun/4.wav 255659 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 87, 'audio': array([[-1.94633358e-05],
#        [-1.94633358e-05],
#        [-1.94633358e-05],
#        ...,
#        [ 1.44747943e-01],
#        [ 1.41361549e-01],
#        [ 1.21807516e-01]], dtype=float32), 'sr': 8000}
# 47 ../test_train_data/2017019880017_sungsoohyun/3.wav 223574 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 87, 'audio': array([[1.2263023e-04],
#        [1.2263023e-04],
#        [1.2263023e-04],
#        ...,
#        [3.2411465e-01],
#        [1.8478604e-01],
#        [2.9069388e-01]], dtype=float32), 'sr': 8000}
# 48 ../test_train_data/2017019880017_sungsoohyun/2.wav 222379 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 87, 'audio': array([[ 4.9686587e-06],
#        [ 4.9686587e-06],
#        [ 4.9686587e-06],
#        ...,
#        [-1.6044760e+00],
#        [-1.3451586e+00],
#        [-8.8267082e-01]], dtype=float32), 'sr': 8000}
# 49 ../test_train_data/2017019880017_sungsoohyun/1.wav 230742 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 87, 'audio': array([[ 6.7261186e-05],
#        [ 6.7261186e-05],
#        [ 6.7261186e-05],
#        ...,
#        [ 1.7839710e+00],
#        [ 2.3329437e+00],
#        [-2.4173987e-01]], dtype=float32), 'sr': 8000}
# 50 ../test_train_data/2017019770012_ladakyeong/5.wav 234486 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 42, 'audio': array([[-6.3168067e-05],
#        [-6.3202555e-05],
#        [-6.3162144e-05],
#        ...,
#        [ 5.3849719e-02],
#        [-6.9853805e-02],
#        [ 1.6359356e-01]], dtype=float32), 'sr': 8000}
# 51 ../test_train_data/2017019770012_ladakyeong/4.wav 241312 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 42, 'audio': array([[ 1.1322596e-04],
#        [ 1.1322596e-04],
#        [ 1.1322596e-04],
#        ...,
#        [ 4.9064130e-01],
#        [ 4.1736406e-01],
#        [-2.6411551e-01]], dtype=float32), 'sr': 8000}
# 52 ../test_train_data/2017019770012_ladakyeong/3.wav 238411 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 42, 'audio': array([[-5.6956840e-05],
#        [-5.6956840e-05],
#        [-5.6956840e-05],
#        ...,
#        [ 2.0587212e-01],
#        [ 2.1886352e-01],
#        [ 1.5187731e-01]], dtype=float32), 'sr': 8000}
# 53 ../test_train_data/2017019770012_ladakyeong/2.wav 251894 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 42, 'audio': array([[-2.8158849e-05],
#        [-2.8158849e-05],
#        [-2.8158849e-05],
#        ...,
#        [-7.9225130e-02],
#        [-9.0218388e-02],
#        [-5.1207975e-02]], dtype=float32), 'sr': 8000}
# 54 ../test_train_data/2017019770012_ladakyeong/1.wav 255307 -0.0 0.9999998
# CUT New length = 10000
# -----------------
# {'class_id': 42, 'audio': array([[-6.0855393e-05],
#        [-6.0855393e-05],
#        [-6.0855393e-05],
#        ...,
#        [ 1.0441563e-01],
#        [ 1.0089123e-01],
#        [ 7.8478366e-02]], dtype=float32), 'sr': 8000}
# 55 ../test_train_data/2017019880001_kimsubin/5.wav 174057 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[ 2.6771819e-05],
#        [ 2.6771819e-05],
#        [ 2.6771819e-05],
#        ...,
#        [-7.8765871e-03],
#        [-5.8377497e-03],
#        [ 8.5469177e-03]], dtype=float32), 'sr': 8000}
# 56 ../test_train_data/2017019880001_kimsubin/4.wav 180187 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[-1.3092944e-05],
#        [-1.3092944e-05],
#        [-1.3092944e-05],
#        ...,
#        [ 8.1746034e-02],
#        [ 3.8067658e-02],
#        [ 1.3821016e-02]], dtype=float32), 'sr': 8000}
# 57 ../test_train_data/2017019880001_kimsubin/3.wav 180930 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[ 2.3299672e-06],
#        [ 2.3299672e-06],
#        [ 2.3299672e-06],
#        ...,
#        [-1.0602015e+00],
#        [-1.4528151e+00],
#        [-1.7819526e+00]], dtype=float32), 'sr': 8000}
# 58 ../test_train_data/2017019880001_kimsubin/2.wav 180745 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[-1.1053517e-05],
#        [-1.1053517e-05],
#        [-1.1053517e-05],
#        ...,
#        [ 5.9331614e-01],
#        [ 2.0746398e+00],
#        [ 3.0737331e+00]], dtype=float32), 'sr': 8000}
# 59 ../test_train_data/2017019880001_kimsubin/1.wav 186875 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[-1.0238086e-05],
#        [-1.0238086e-05],
#        [-1.0238086e-05],
#        ...,
#        [-3.2621118e-01],
#        [-2.2515143e-01],
#        [ 6.1012398e-02]], dtype=float32), 'sr': 8000}
# 60 ../test_train_data/2017019880005_kimjihyeon/5.wav 257136 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 75, 'audio': array([[-0.00591618],
#        [-0.02199315],
#        [-0.0210896 ],
#        ...,
#        [ 0.6975058 ],
#        [ 0.4829605 ],
#        [ 0.23482671]], dtype=float32), 'sr': 8000}
# 61 ../test_train_data/2017019880005_kimjihyeon/4.wav 247686 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 75, 'audio': array([[-0.03430287],
#        [-0.06379325],
#        [-0.03869988],
#        ...,
#        [ 0.08281998],
#        [ 0.0758208 ],
#        [ 0.0499674 ]], dtype=float32), 'sr': 8000}
# 62 ../test_train_data/2017019880005_kimjihyeon/3.wav 254115 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 75, 'audio': array([[-0.03270176],
#        [-0.09155422],
#        [-0.11211705],
#        ...,
#        [ 0.7362706 ],
#        [ 0.7111027 ],
#        [ 0.6214093 ]], dtype=float32), 'sr': 8000}
# 63 ../test_train_data/2017019880005_kimjihyeon/2.wav 228643 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 75, 'audio': array([[-0.02415845],
#        [-0.027584  ],
#        [-0.01633685],
#        ...,
#        [-1.4817413 ],
#        [-0.5755072 ],
#        [ 0.03097891]], dtype=float32), 'sr': 8000}
# 64 ../test_train_data/2017019880005_kimjihyeon/1.wav 225571 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 75, 'audio': array([[-0.02561466],
#        [-0.03529166],
#        [-0.04291368],
#        ...,
#        [ 1.4398415 ],
#        [ 1.0769807 ],
#        [ 0.63339823]], dtype=float32), 'sr': 8000}
# 65 ../test_train_data/2017019880004_myeongjaewon/5.wav 195977 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 74, 'audio': array([[ 2.5025773e-04],
#        [ 2.5025773e-04],
#        [ 2.5025773e-04],
#        ...,
#        [-8.6063705e-03],
#        [-5.2121758e-01],
#        [-9.9727517e-01]], dtype=float32), 'sr': 8000}
# 66 ../test_train_data/2017019880004_myeongjaewon/4.wav 197277 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 74, 'audio': array([[0.00034221],
#        [0.00034221],
#        [0.00034221],
#        ...,
#        [0.10114516],
#        [0.03500539],
#        [0.08619635]], dtype=float32), 'sr': 8000}
# 67 ../test_train_data/2017019880004_myeongjaewon/3.wav 188361 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 74, 'audio': array([[1.4721421e-03],
#        [1.4721421e-03],
#        [1.4721421e-03],
#        ...,
#        [2.3207169e+00],
#        [2.3712478e+00],
#        [1.4542586e+00]], dtype=float32), 'sr': 8000}
# 68 ../test_train_data/2017019880004_myeongjaewon/2.wav 195977 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 74, 'audio': array([[ 0.00175906],
#        [ 0.00175906],
#        [ 0.00175906],
#        ...,
#        [-1.1293193 ],
#        [-0.80543196],
#        [-0.4652431 ]], dtype=float32), 'sr': 8000}
# 69 ../test_train_data/2017019880004_myeongjaewon/1.wav 209352 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 74, 'audio': array([[0.00247008],
#        [0.00247008],
#        [0.00247008],
#        ...,
#        [0.7160804 ],
#        [0.7442712 ],
#        [2.1989686 ]], dtype=float32), 'sr': 8000}
# 70 ../test_train_data/2017019740025_ahnjeongsuk/5.wav 218112 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 24, 'audio': array([[-0.00016581],
#        [-0.00016581],
#        [-0.00016581],
#        ...,
#        [-0.09386405],
#        [-0.09894408],
#        [-0.12773089]], dtype=float32), 'sr': 8000}
# 71 ../test_train_data/2017019740025_ahnjeongsuk/4.wav 209920 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 24, 'audio': array([[-8.3599170e-06],
#        [-8.3599170e-06],
#        [-8.3599170e-06],
#        ...,
#        [ 4.1291252e-01],
#        [ 4.8965961e-01],
#        [ 7.0530802e-01]], dtype=float32), 'sr': 8000}
# 72 ../test_train_data/2017019740025_ahnjeongsuk/3.wav 217088 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 24, 'audio': array([[-1.7949249e-06],
#        [-1.7949249e-06],
#        [-1.7949249e-06],
#        ...,
#        [-6.6830881e-02],
#        [-6.7369826e-02],
#        [-7.2220318e-02]], dtype=float32), 'sr': 8000}
# 73 ../test_train_data/2017019740025_ahnjeongsuk/2.wav 217088 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 24, 'audio': array([[-0.00023189],
#        [-0.00023189],
#        [-0.00023189],
#        ...,
#        [-0.00775872],
#        [-0.00891669],
#        [-0.01933846]], dtype=float32), 'sr': 8000}
# 74 ../test_train_data/2017019740025_ahnjeongsuk/1.wav 245760 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 24, 'audio': array([[ 0.00029287],
#        [ 0.00029287],
#        [ 0.00029287],
#        ...,
#        [-0.02171337],
#        [-0.01712874],
#        [-0.01667028]], dtype=float32), 'sr': 8000}
# 75 ../test_train_data/2017019880019_wonsonghee/5.wav 266937 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 89, 'audio': array([[-2.6311827e-05],
#        [-2.6311827e-05],
#        [-2.6311827e-05],
#        ...,
#        [-2.5731587e-01],
#        [-1.8046986e-02],
#        [ 2.3130444e-01]], dtype=float32), 'sr': 8000}
# 76 ../test_train_data/2017019880019_wonsonghee/4.wav 271395 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 89, 'audio': array([[-3.4386983e-05],
#        [-3.4386983e-05],
#        [-3.4386983e-05],
#        ...,
#        [ 3.2208271e-02],
#        [ 3.1643201e-02],
#        [ 3.1013118e-02]], dtype=float32), 'sr': 8000}
# 77 ../test_train_data/2017019880019_wonsonghee/3.wav 264522 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 89, 'audio': array([[ 9.4775288e-07],
#        [ 9.4775288e-07],
#        [ 9.4775288e-07],
#        ...,
#        [-5.3471494e-03],
#        [-5.0991327e-03],
#        [-5.1024775e-03]], dtype=float32), 'sr': 8000}
# 78 ../test_train_data/2017019880019_wonsonghee/2.wav 260621 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 89, 'audio': array([[-5.7773946e-06],
#        [-5.7773946e-06],
#        [-5.7773946e-06],
#        ...,
#        [-1.1136498e-02],
#        [-9.4490787e-03],
#        [-7.1524945e-03]], dtype=float32), 'sr': 8000}
# 79 ../test_train_data/2017019880019_wonsonghee/1.wav 271395 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 89, 'audio': array([[-3.8390326e-06],
#        [-3.8390326e-06],
#        [-3.8390326e-06],
#        ...,
#        [-8.8525955e-03],
#        [-8.9062126e-03],
#        [-9.8507963e-03]], dtype=float32), 'sr': 8000}
# 80 ../test_train_data/2017019770008_parksomi/5.wav 214553 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 38, 'audio': array([[-7.421394e-06],
#        [-7.421394e-06],
#        [-7.421394e-06],
#        ...,
#        [ 7.082107e-01],
#        [ 7.484347e-01],
#        [ 8.128866e-01]], dtype=float32), 'sr': 8000}
# 81 ../test_train_data/2017019770008_parksomi/4.wav 216039 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 38, 'audio': array([[-1.9338608e-05],
#        [-1.9338608e-05],
#        [-1.9338608e-05],
#        ...,
#        [-5.2574903e-01],
#        [-5.7672149e-01],
#        [-4.6508384e-01]], dtype=float32), 'sr': 8000}
# 82 ../test_train_data/2017019770008_parksomi/3.wav 216782 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 38, 'audio': array([[7.7418927e-06],
#        [7.7418927e-06],
#        [7.7418927e-06],
#        ...,
#        [1.0859219e+00],
#        [9.5664668e-01],
#        [5.2556580e-01]], dtype=float32), 'sr': 8000}
# 83 ../test_train_data/2017019770008_parksomi/2.wav 242045 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 38, 'audio': array([[ 2.5071276e-05],
#        [ 2.5071276e-05],
#        [ 2.5071276e-05],
#        ...,
#        [-5.9522170e-01],
#        [ 1.9949715e-01],
#        [ 3.1567436e-01]], dtype=float32), 'sr': 8000}
# 84 ../test_train_data/2017019770008_parksomi/1.wav 236287 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 38, 'audio': array([[-9.5084006e-06],
#        [-9.5084006e-06],
#        [-9.5084006e-06],
#        ...,
#        [ 5.9796190e-01],
#        [ 3.8425383e-01],
#        [ 4.6753693e-01]], dtype=float32), 'sr': 8000}
# 85 ../test_train_data/2017019880007_hwanghyebin/5.wav 253377 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 77, 'audio': array([[-3.0729250e-05],
#        [-3.0729250e-05],
#        [-3.0729250e-05],
#        ...,
#        [-1.7548420e+00],
#        [-1.5525473e+00],
#        [-1.2578015e+00]], dtype=float32), 'sr': 8000}
# 86 ../test_train_data/2017019880007_hwanghyebin/4.wav 245017 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 77, 'audio': array([[8.6120359e-05],
#        [8.6120359e-05],
#        [8.6120359e-05],
#        ...,
#        [7.2912626e-02],
#        [2.2866604e-01],
#        [1.7573543e-01]], dtype=float32), 'sr': 8000}
# 87 ../test_train_data/2017019880007_hwanghyebin/3.wav 248547 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 77, 'audio': array([[ 7.92095088e-05],
#        [ 7.92095088e-05],
#        [ 7.92095088e-05],
#        ...,
#        [-2.49127865e-01],
#        [ 2.44891904e-02],
#        [-1.11782216e-01]], dtype=float32), 'sr': 8000}
# 88 ../test_train_data/2017019880007_hwanghyebin/2.wav 250962 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 77, 'audio': array([[ 2.1174148e-05],
#        [ 2.1174148e-05],
#        [ 2.1174148e-05],
#        ...,
#        [-4.1814927e-02],
#        [-1.2813212e-01],
#        [ 8.3296031e-02]], dtype=float32), 'sr': 8000}
# 89 ../test_train_data/2017019880007_hwanghyebin/1.wav 252819 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 77, 'audio': array([[-1.8792625e-05],
#        [-1.8792625e-05],
#        [-1.8792625e-05],
#        ...,
#        [-1.4537798e+00],
#        [-1.5422108e+00],
#        [-1.3656894e+00]], dtype=float32), 'sr': 8000}
# 90 ../test_train_data/2017019880012_kimsongyi/5.wav 233814 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 82, 'audio': array([[-5.0295719e-05],
#        [-5.0295719e-05],
#        [-5.0295719e-05],
#        ...,
#        [ 9.2676066e-02],
#        [ 8.9143455e-02],
#        [ 6.8116099e-02]], dtype=float32), 'sr': 8000}
# 91 ../test_train_data/2017019880012_kimsongyi/4.wav 228523 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 82, 'audio': array([[6.4895888e-05],
#        [6.4895888e-05],
#        [6.4895888e-05],
#        ...,
#        [3.8817938e-02],
#        [5.1356807e-02],
#        [3.9619066e-02]], dtype=float32), 'sr': 8000}
# 92 ../test_train_data/2017019880012_kimsongyi/3.wav 229718 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 82, 'audio': array([[9.3893017e-05],
#        [9.3893017e-05],
#        [9.3893017e-05],
#        ...,
#        [1.2776999e-01],
#        [1.0639878e-01],
#        [1.4960933e-01]], dtype=float32), 'sr': 8000}
# 93 ../test_train_data/2017019880012_kimsongyi/2.wav 235862 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 82, 'audio': array([[ 2.3484101e-05],
#        [ 2.3484101e-05],
#        [ 2.3484101e-05],
#        ...,
#        [-3.3808816e-02],
#        [-2.6820526e-02],
#        [-2.2809424e-02]], dtype=float32), 'sr': 8000}
# 94 ../test_train_data/2017019880012_kimsongyi/1.wav 247638 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 82, 'audio': array([[-7.3500655e-07],
#        [-7.3500655e-07],
#        [-7.3500655e-07],
#        ...,
#        [ 9.2300080e-02],
#        [ 1.1492589e-01],
#        [ 8.9829050e-02]], dtype=float32), 'sr': 8000}
# 95 ../test_train_data/2017019740006_kangsubin/5.wav 252262 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 5, 'audio': array([[-2.9371827e-07],
#        [-2.9371827e-07],
#        [-2.9371827e-07],
#        ...,
#        [ 1.5438800e+00],
#        [ 1.4503914e+00],
#        [ 1.0652454e+00]], dtype=float32), 'sr': 8000}
# 96 ../test_train_data/2017019740006_kangsubin/4.wav 258206 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 5, 'audio': array([[-1.0708673e-05],
#        [-1.0708673e-05],
#        [-1.0708673e-05],
#        ...,
#        [ 7.0134997e-02],
#        [ 8.5648701e-02],
#        [ 8.9419700e-02]], dtype=float32), 'sr': 8000}
# 97 ../test_train_data/2017019740006_kangsubin/3.wav 262850 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 5, 'audio': array([[-1.7209193e-05],
#        [-1.7209193e-05],
#        [-1.7209193e-05],
#        ...,
#        [-7.5868465e-02],
#        [ 3.6545631e-02],
#        [ 9.1927670e-02]], dtype=float32), 'sr': 8000}
# 98 ../test_train_data/2017019740006_kangsubin/2.wav 251705 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 5, 'audio': array([[-8.5944030e-06],
#        [-8.5944030e-06],
#        [-8.5944030e-06],
#        ...,
#        [ 2.0855560e+00],
#        [ 2.1451216e+00],
#        [ 2.1382694e+00]], dtype=float32), 'sr': 8000}
# 99 ../test_train_data/2017019740006_kangsubin/1.wav 250219 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 5, 'audio': array([[-2.2133852e-05],
#        [-2.2133852e-05],
#        [-2.2133852e-05],
#        ...,
#        [-4.9345735e-01],
#        [-5.7262945e-01],
#        [-6.8534607e-01]], dtype=float32), 'sr': 8000}
# 100 ../test_train_data/2017019770017_hansohee/5.wav 269644 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 47, 'audio': array([[ 0.00349712],
#        [ 0.00582835],
#        [ 0.00664637],
#        ...,
#        [-1.3906012 ],
#        [-1.430701  ],
#        [-1.399698  ]], dtype=float32), 'sr': 8000}
# 101 ../test_train_data/2017019770017_hansohee/4.wav 283239 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 47, 'audio': array([[-0.02685392],
#        [-0.04050423],
#        [-0.02843139],
#        ...,
#        [ 0.7769398 ],
#        [ 0.9818952 ],
#        [ 1.1436118 ]], dtype=float32), 'sr': 8000}
# 102 ../test_train_data/2017019770017_hansohee/3.wav 274283 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 47, 'audio': array([[ 0.01880782],
#        [ 0.03483988],
#        [ 0.02260841],
#        ...,
#        [-0.6552705 ],
#        [-0.71960866],
#        [-0.74847835]], dtype=float32), 'sr': 8000}
# 103 ../test_train_data/2017019770017_hansohee/2.wav 267592 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 47, 'audio': array([[0.00217616],
#        [0.00319244],
#        [0.00430294],
#        ...,
#        [0.02653635],
#        [0.08110059],
#        [0.2352123 ]], dtype=float32), 'sr': 8000}
# 104 ../test_train_data/2017019770017_hansohee/1.wav 273089 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 47, 'audio': array([[-0.01662825],
#        [-0.00687883],
#        [ 0.00787622],
#        ...,
#        [-1.06487   ],
#        [-0.79418826],
#        [-0.7216889 ]], dtype=float32), 'sr': 8000}
# 105 ../test_train_data/2017019880022_kimjaein/5.wav 224758 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 92, 'audio': array([[ 5.7250087e-04],
#        [-8.5570267e-04],
#        [ 2.8695115e-03],
#        ...,
#        [ 5.3505726e+00],
#        [ 5.8390961e+00],
#        [ 4.5045128e+00]], dtype=float32), 'sr': 8000}
# 106 ../test_train_data/2017019880022_kimjaein/4.wav 215712 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 92, 'audio': array([[ 2.26976568e-04],
#        [-1.05393665e-04],
#        [ 2.53143278e-03],
#        ...,
#        [ 1.52039036e-01],
#        [ 2.25653514e-01],
#        [-2.97431648e-01]], dtype=float32), 'sr': 8000}
# 107 ../test_train_data/2017019880022_kimjaein/3.wav 211958 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 92, 'audio': array([[ 0.00042702],
#        [-0.00095907],
#        [ 0.00278437],
#        ...,
#        [ 0.06752339],
#        [ 0.05106178],
#        [-0.07365638]], dtype=float32), 'sr': 8000}
# 108 ../test_train_data/2017019880022_kimjaein/2.wav 221856 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 92, 'audio': array([[ 0.00157918],
#        [ 0.00191473],
#        [ 0.00830124],
#        ...,
#        [-0.46553633],
#        [ 0.09283049],
#        [-0.5449107 ]], dtype=float32), 'sr': 8000}
# 109 ../test_train_data/2017019880022_kimjaein/1.wav 225440 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 92, 'audio': array([[-4.9982107e-05],
#        [-6.9989986e-04],
#        [ 1.5709603e-03],
#        ...,
#        [-6.6699314e-01],
#        [-7.3866677e-01],
#        [-5.8425272e-01]], dtype=float32), 'sr': 8000}
# 110 ../test_train_data/2017019770013_janghyomin/5.wav 218443 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 43, 'audio': array([[-0.00109244],
#        [ 0.00066157],
#        [-0.00154163],
#        ...,
#        [ 0.01002656],
#        [ 0.01761308],
#        [ 0.00964815]], dtype=float32), 'sr': 8000}
# 111 ../test_train_data/2017019770013_janghyomin/4.wav 219126 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 43, 'audio': array([[-7.9488539e-04],
#        [ 1.4875403e-03],
#        [-9.6893689e-04],
#        ...,
#        [-2.0236235e+00],
#        [-1.7948147e+00],
#        [-1.4250221e+00]], dtype=float32), 'sr': 8000}
# 112 ../test_train_data/2017019770013_janghyomin/3.wav 215542 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 43, 'audio': array([[-0.00191654],
#        [ 0.00245314],
#        [-0.00232412],
#        ...,
#        [-0.10662506],
#        [-0.7741731 ],
#        [-0.8516503 ]], dtype=float32), 'sr': 8000}
# 113 ../test_train_data/2017019770013_janghyomin/2.wav 217590 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 43, 'audio': array([[-0.00147204],
#        [ 0.00151948],
#        [-0.00066438],
#        ...,
#        [ 0.00460415],
#        [ 0.08221631],
#        [ 0.19426014]], dtype=float32), 'sr': 8000}
# 114 ../test_train_data/2017019770013_janghyomin/1.wav 215200 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 43, 'audio': array([[-9.4733818e-04],
#        [ 6.4932468e-04],
#        [-1.4933468e-03],
#        ...,
#        [ 4.6417174e+00],
#        [ 4.7759624e+00],
#        [ 4.6462412e+00]], dtype=float32), 'sr': 8000}
# 115 ../test_train_data/2017019880039_seojuyeon/5.wav 233472 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 109, 'audio': array([[ 2.2165510e-05],
#        [ 2.2165510e-05],
#        [ 2.2165510e-05],
#        ...,
#        [-1.0164554e+00],
#        [-7.9458839e-01],
#        [-5.7329345e-01]], dtype=float32), 'sr': 8000}
# 116 ../test_train_data/2017019880039_seojuyeon/4.wav 233814 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 109, 'audio': array([[-2.0630299e-05],
#        [-2.0630299e-05],
#        [-2.0630299e-05],
#        ...,
#        [ 4.2484307e-01],
#        [-7.1730040e-02],
#        [-5.8621311e-01]], dtype=float32), 'sr': 8000}
# 117 ../test_train_data/2017019880039_seojuyeon/3.wav 239787 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 109, 'audio': array([[ 6.9484588e-05],
#        [ 6.9484588e-05],
#        [ 6.9484588e-05],
#        ...,
#        [-2.2855425e+00],
#        [-2.3591070e+00],
#        [-2.6585078e+00]], dtype=float32), 'sr': 8000}
# 118 ../test_train_data/2017019880039_seojuyeon/2.wav 232448 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 109, 'audio': array([[-4.9309336e-05],
#        [-4.9309336e-05],
#        [-4.9309336e-05],
#        ...,
#        [ 5.3748399e-01],
#        [ 1.8288013e-01],
#        [-2.2350803e-01]], dtype=float32), 'sr': 8000}
# 119 ../test_train_data/2017019880039_seojuyeon/1.wav 231936 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 109, 'audio': array([[6.1291234e-06],
#        [6.1291234e-06],
#        [6.1291234e-06],
#        ...,
#        [2.1984485e-01],
#        [6.3207559e-02],
#        [8.9033596e-02]], dtype=float32), 'sr': 8000}
# 120 ../test_train_data/2017019770036_yuminji/5.wav 232960 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 66, 'audio': array([[-0.00059695],
#        [-0.00059695],
#        [-0.00059695],
#        ...,
#        [-0.27784622],
#        [-0.4854468 ],
#        [-0.5756509 ]], dtype=float32), 'sr': 8000}
# 121 ../test_train_data/2017019770036_yuminji/4.wav 238592 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 66, 'audio': array([[-0.00051209],
#        [-0.00051209],
#        [-0.00051209],
#        ...,
#        [-0.22016059],
#        [-0.03462774],
#        [ 0.31661665]], dtype=float32), 'sr': 8000}
# 122 ../test_train_data/2017019770036_yuminji/3.wav 228352 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 66, 'audio': array([[-6.8244274e-04],
#        [-6.8244274e-04],
#        [-6.8244274e-04],
#        ...,
#        [-5.1881915e-01],
#        [-6.7742169e-01],
#        [-7.2482884e-01]], dtype=float32), 'sr': 8000}
# 123 ../test_train_data/2017019770036_yuminji/2.wav 239104 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 66, 'audio': array([[-0.0004803 ],
#        [-0.0004803 ],
#        [-0.0004803 ],
#        ...,
#        [-0.10199414],
#        [-0.12868173],
#        [-0.17979112]], dtype=float32), 'sr': 8000}
# 124 ../test_train_data/2017019770036_yuminji/1.wav 226816 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 66, 'audio': array([[-0.00056857],
#        [-0.00056857],
#        [-0.00056857],
#        ...,
#        [ 0.43623173],
#        [-0.02154143],
#        [-0.42273885]], dtype=float32), 'sr': 8000}
# 125 ../test_train_data/2017019880024_hanyukyung/5.wav 233500 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 94, 'audio': array([[-0.00047512],
#        [-0.00048015],
#        [-0.00047439],
#        ...,
#        [ 0.00256822],
#        [ 0.00071339],
#        [-0.00433287]], dtype=float32), 'sr': 8000}
# 126 ../test_train_data/2017019880024_hanyukyung/4.wav 213996 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 94, 'audio': array([[-0.00034038],
#        [-0.00034065],
#        [-0.0003404 ],
#        ...,
#        [-0.00029065],
#        [-0.00044863],
#        [-0.00036469]], dtype=float32), 'sr': 8000}
# 127 ../test_train_data/2017019880024_hanyukyung/3.wav 227928 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 94, 'audio': array([[-0.00073988],
#        [-0.00074258],
#        [-0.00073961],
#        ...,
#        [-0.00063327],
#        [-0.00091763],
#        [-0.00044188]], dtype=float32), 'sr': 8000}
# 128 ../test_train_data/2017019880024_hanyukyung/2.wav 220311 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 94, 'audio': array([[-0.00057112],
#        [-0.00057112],
#        [-0.00057112],
#        ...,
#        [-0.00057115],
#        [-0.00057112],
#        [-0.00057108]], dtype=float32), 'sr': 8000}
# 129 ../test_train_data/2017019880024_hanyukyung/1.wav 223284 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 94, 'audio': array([[-0.00044371],
#        [-0.00044371],
#        [-0.00044371],
#        ...,
#        [-0.00044375],
#        [-0.00044371],
#        [-0.00044367]], dtype=float32), 'sr': 8000}
# 130 ../test_train_data/2017019880031_ahnjiwoo/5.wav 255830 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 101, 'audio': array([[-8.7366439e-05],
#        [-8.7366439e-05],
#        [-8.7366439e-05],
#        ...,
#        [ 8.9232549e-03],
#        [ 1.7697557e-03],
#        [-7.3007221e-04]], dtype=float32), 'sr': 8000}
# 131 ../test_train_data/2017019880031_ahnjiwoo/4.wav 253782 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 101, 'audio': array([[-7.495986e-05],
#        [-7.495986e-05],
#        [-7.495986e-05],
#        ...,
#        [ 9.099936e-03],
#        [ 7.871719e-03],
#        [ 8.127262e-03]], dtype=float32), 'sr': 8000}
# 132 ../test_train_data/2017019880031_ahnjiwoo/3.wav 245590 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 101, 'audio': array([[4.9164148e-05],
#        [4.9164148e-05],
#        [4.9164148e-05],
#        ...,
#        [3.0724483e-02],
#        [2.9083006e-02],
#        [2.4902368e-02]], dtype=float32), 'sr': 8000}
# 133 ../test_train_data/2017019880031_ahnjiwoo/2.wav 260096 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 101, 'audio': array([[-8.1464983e-05],
#        [-8.1464983e-05],
#        [-8.1464983e-05],
#        ...,
#        [ 2.0485276e-02],
#        [ 2.5566513e-02],
#        [ 2.6823699e-02]], dtype=float32), 'sr': 8000}
# 134 ../test_train_data/2017019880031_ahnjiwoo/1.wav 260950 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 101, 'audio': array([[ 2.6735614e-05],
#        [ 2.6735614e-05],
#        [ 2.6735614e-05],
#        ...,
#        [-4.9870401e-03],
#        [-1.6247994e-03],
#        [-4.7037895e-03]], dtype=float32), 'sr': 8000}
# 135 ../test_train_data/2017019740005_moonyeonwoo/5.wav 201547 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 4, 'audio': array([[1.6966300e-02],
#        [2.4443774e-02],
#        [3.5086463e-04],
#        ...,
#        [9.0883386e-01],
#        [8.6419535e-01],
#        [8.1382203e-01]], dtype=float32), 'sr': 8000}
# 136 ../test_train_data/2017019740005_moonyeonwoo/4.wav 201376 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 4, 'audio': array([[ 0.01128076],
#        [-0.00065449],
#        [-0.02136131],
#        ...,
#        [-0.13358547],
#        [-0.1538612 ],
#        [-0.18105641]], dtype=float32), 'sr': 8000}
# 137 ../test_train_data/2017019740005_moonyeonwoo/3.wav 187894 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 4, 'audio': array([[ 0.00620129],
#        [-0.00177455],
#        [-0.00344637],
#        ...,
#        [ 0.9111818 ],
#        [ 1.0294359 ],
#        [ 0.57031393]], dtype=float32), 'sr': 8000}
# 138 ../test_train_data/2017019740005_moonyeonwoo/2.wav 212470 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 4, 'audio': array([[0.00161356],
#        [0.00311527],
#        [0.00444696],
#        ...,
#        [1.2809883 ],
#        [1.2589904 ],
#        [0.72374606]], dtype=float32), 'sr': 8000}
# 139 ../test_train_data/2017019740005_moonyeonwoo/1.wav 221515 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 4, 'audio': array([[ 0.00497629],
#        [ 0.01260146],
#        [ 0.01744614],
#        ...,
#        [-0.02516209],
#        [-0.05212294],
#        [-0.05422848]], dtype=float32), 'sr': 8000}
# 140 ../test_train_data/2017019770009_yuminji/5.wav 232960 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 39, 'audio': array([[-0.00059695],
#        [-0.00059695],
#        [-0.00059695],
#        ...,
#        [-0.27784622],
#        [-0.4854468 ],
#        [-0.5756509 ]], dtype=float32), 'sr': 8000}
# 141 ../test_train_data/2017019770009_yuminji/4.wav 238592 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 39, 'audio': array([[-0.00051209],
#        [-0.00051209],
#        [-0.00051209],
#        ...,
#        [-0.22016059],
#        [-0.03462774],
#        [ 0.31661665]], dtype=float32), 'sr': 8000}
# 142 ../test_train_data/2017019770009_yuminji/3.wav 228352 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 39, 'audio': array([[-6.8244274e-04],
#        [-6.8244274e-04],
#        [-6.8244274e-04],
#        ...,
#        [-5.1881915e-01],
#        [-6.7742169e-01],
#        [-7.2482884e-01]], dtype=float32), 'sr': 8000}
# 143 ../test_train_data/2017019770009_yuminji/2.wav 239104 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 39, 'audio': array([[-0.0004803 ],
#        [-0.0004803 ],
#        [-0.0004803 ],
#        ...,
#        [-0.10199414],
#        [-0.12868173],
#        [-0.17979112]], dtype=float32), 'sr': 8000}
# 144 ../test_train_data/2017019770009_yuminji/1.wav 226816 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 39, 'audio': array([[-0.00056857],
#        [-0.00056857],
#        [-0.00056857],
#        ...,
#        [ 0.43623173],
#        [-0.02154143],
#        [-0.42273885]], dtype=float32), 'sr': 8000}
# 145 ../test_train_data/2017019770007_simseungmin/5.wav 213810 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 37, 'audio': array([[-1.0627580e-04],
#        [-1.0627580e-04],
#        [-1.0627580e-04],
#        ...,
#        [ 2.8787839e-01],
#        [ 7.0730108e-01],
#        [ 1.3478084e+00]], dtype=float32), 'sr': 8000}
# 146 ../test_train_data/2017019770007_simseungmin/4.wav 220497 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 37, 'audio': array([[-9.29071975e-05],
#        [-9.29071975e-05],
#        [-9.29071975e-05],
#        ...,
#        [-2.13475898e-01],
#        [-1.82825521e-01],
#        [-1.18653655e-01]], dtype=float32), 'sr': 8000}
# 147 ../test_train_data/2017019770007_simseungmin/3.wav 252076 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 37, 'audio': array([[-6.9125864e-04],
#        [-6.9125864e-04],
#        [-6.9125864e-04],
#        ...,
#        [-1.1425052e+00],
#        [-1.0454838e-01],
#        [ 4.4110164e-01]], dtype=float32), 'sr': 8000}
# 148 ../test_train_data/2017019770007_simseungmin/2.wav 220311 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 37, 'audio': array([[-9.9616002e-05],
#        [-9.9616002e-05],
#        [-9.9616002e-05],
#        ...,
#        [-3.6618900e-01],
# ...
#        [1.8134236e-02]], dtype=float32), 'sr': 8000}
# 526 ../test_train_data/2017019740004_parksohui/4.wav 236544 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 3, 'audio': array([[ 4.1694508e-05],
#        [ 4.1694508e-05],
#        [ 4.1694508e-05],
#        ...,
#        [-2.2236133e-02],
#        [-2.0449275e-02],
#        [-1.5420795e-02]], dtype=float32), 'sr': 8000}
# 527 ../test_train_data/2017019740004_parksohui/3.wav 239275 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 3, 'audio': array([[ 5.0020368e-05],
#        [ 5.0020368e-05],
#        [ 5.0020368e-05],
#        ...,
#        [-1.1618400e-02],
#        [-1.0666723e-02],
#        [-1.3435443e-02]], dtype=float32), 'sr': 8000}
# 528 ../test_train_data/2017019740004_parksohui/2.wav 237568 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 3, 'audio': array([[-5.4704735e-05],
#        [-5.4704735e-05],
#        [-5.4704735e-05],
#        ...,
#        [ 5.3107101e-03],
#        [ 2.1520130e-02],
#        [ 4.2331032e-02]], dtype=float32), 'sr': 8000}
# 529 ../test_train_data/2017019740004_parksohui/1.wav 244395 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 3, 'audio': array([[6.2304796e-05],
#        [6.2304796e-05],
#        [6.2304796e-05],
#        ...,
#        [2.6750593e-02],
#        [2.5905415e-02],
#        [3.2634504e-02]], dtype=float32), 'sr': 8000}
# 530 ../test_train_data/2017019740014_leesumin/5.wav 249163 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 13, 'audio': array([[ 0.00168815],
#        [ 0.0024458 ],
#        [-0.00644404],
#        ...,
#        [-0.02819586],
#        [ 0.01403883],
#        [ 0.09261337]], dtype=float32), 'sr': 8000}
# 531 ../test_train_data/2017019740014_leesumin/4.wav 253259 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 13, 'audio': array([[ 0.00018025],
#        [ 0.00056579],
#        [-0.00049918],
#        ...,
#        [ 0.02179821],
#        [ 0.03399308],
#        [ 0.04373927]], dtype=float32), 'sr': 8000}
# 532 ../test_train_data/2017019740014_leesumin/3.wav 247235 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 13, 'audio': array([[ 1.0633960e-04],
#        [-3.1245247e-04],
#        [-5.3997424e-05],
#        ...,
#        [ 7.7118270e-02],
#        [ 9.2024252e-02],
#        [ 1.0388532e-01]], dtype=float32), 'sr': 8000}
# 533 ../test_train_data/2017019740014_leesumin/2.wav 240971 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 13, 'audio': array([[ 0.00045977],
#        [ 0.00088498],
#        [-0.00175314],
#        ...,
#        [-0.01840266],
#        [-0.02574469],
#        [-0.01375394]], dtype=float32), 'sr': 8000}
# 534 ../test_train_data/2017019740014_leesumin/1.wav 220662 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 13, 'audio': array([[-2.4877168e-05],
#        [ 5.6035171e-04],
#        [-3.3237445e-04],
#        ...,
#        [-6.5907918e-02],
#        [-5.3359866e-02],
#        [-5.0384350e-02]], dtype=float32), 'sr': 8000}
# 535 ../test_train_data/2017019770014_parkeunbi/5.wav 224398 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 44, 'audio': array([[ 7.0267770e-04],
#        [ 7.0267770e-04],
#        [ 7.0267770e-04],
#        ...,
#        [ 8.3693981e-01],
#        [-3.8557881e-01],
#        [ 1.0499807e-01]], dtype=float32), 'sr': 8000}
# 536 ../test_train_data/2017019770014_parkeunbi/4.wav 234429 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 44, 'audio': array([[0.00056987],
#        [0.00056987],
#        [0.00056987],
#        ...,
#        [0.24492249],
#        [0.15392034],
#        [0.16334854]], dtype=float32), 'sr': 8000}
# 537 ../test_train_data/2017019770014_parkeunbi/3.wav 232572 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 44, 'audio': array([[ 0.00076539],
#        [ 0.00076539],
#        [ 0.00076539],
#        ...,
#        [ 0.15893935],
#        [ 0.04952007],
#        [-0.66897786]], dtype=float32), 'sr': 8000}
# 538 ../test_train_data/2017019770014_parkeunbi/2.wav 243531 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 44, 'audio': array([[ 4.0454979e-04],
#        [ 4.0454979e-04],
#        [ 4.0454979e-04],
#        ...,
#        [ 1.9403086e+00],
#        [-2.4006669e-01],
#        [-1.6987510e+00]], dtype=float32), 'sr': 8000}
# 539 ../test_train_data/2017019770014_parkeunbi/1.wav 237959 -0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 44, 'audio': array([[5.3823087e-04],
#        [5.3823087e-04],
#        [5.3823087e-04],
#        ...,
#        [1.6800846e+00],
#        [1.7483159e+00],
#        [1.9416327e+00]], dtype=float32), 'sr': 8000}
# 540 ../test_train_data/2017019740009_shindonghwan/5.wav 216064 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 8, 'audio': array([[ 2.4493855e-05],
#        [ 2.4493855e-05],
#        [ 2.4493855e-05],
#        ...,
#        [-5.4099973e-02],
#        [-3.3960637e-02],
#        [-1.5080009e-02]], dtype=float32), 'sr': 8000}
# 541 ../test_train_data/2017019740009_shindonghwan/4.wav 206848 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 8, 'audio': array([[-1.3334451e-04],
#        [-1.3334451e-04],
#        [-1.3334451e-04],
#        ...,
#        [ 9.5561039e-01],
#        [ 9.5138454e-01],
#        [ 9.9293864e-01]], dtype=float32), 'sr': 8000}
# 542 ../test_train_data/2017019740009_shindonghwan/3.wav 204800 0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 8, 'audio': array([[ 8.2155231e-05],
#        [ 8.2155231e-05],
#        [ 8.2155231e-05],
#        ...,
#        [-3.6249223e+00],
#        [-3.7778203e+00],
#        [-3.6201067e+00]], dtype=float32), 'sr': 8000}
# 543 ../test_train_data/2017019740009_shindonghwan/2.wav 196608 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 8, 'audio': array([[-5.9323709e-05],
#        [-5.9323709e-05],
#        [-5.9323709e-05],
#        ...,
#        [ 5.2338481e-02],
#        [ 2.8788906e-02],
#        [ 5.2393307e-03]], dtype=float32), 'sr': 8000}
# 544 ../test_train_data/2017019740009_shindonghwan/1.wav 227328 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 8, 'audio': array([[ 4.5629607e-05],
#        [ 4.5629607e-05],
#        [ 4.5629607e-05],
#        ...,
#        [-3.1404417e+00],
#        [-3.2574964e+00],
#        [-3.3074586e+00]], dtype=float32), 'sr': 8000}
# 545 ../test_train_data/2017019740011_kimhyeryeong/5.wav 234496 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 10, 'audio': array([[ 8.2629922e-05],
#        [ 8.2629922e-05],
#        [ 8.2629922e-05],
#        ...,
#        [-8.6087674e-01],
#        [ 1.3670842e-01],
#        [ 1.1919180e+00]], dtype=float32), 'sr': 8000}
# 546 ../test_train_data/2017019740011_kimhyeryeong/4.wav 238592 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 10, 'audio': array([[-8.0248123e-05],
#        [-8.0248123e-05],
#        [-8.0248123e-05],
#        ...,
#        [ 1.8952377e+00],
#        [ 1.7126193e+00],
#        [ 1.4967383e+00]], dtype=float32), 'sr': 8000}
# 547 ../test_train_data/2017019740011_kimhyeryeong/3.wav 239616 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 10, 'audio': array([[-4.5032239e-06],
#        [-4.5032239e-06],
#        [-4.5032239e-06],
#        ...,
#        [-1.2353605e-02],
#        [-1.2019845e-02],
#        [-1.1352326e-02]], dtype=float32), 'sr': 8000}
# 548 ../test_train_data/2017019740011_kimhyeryeong/2.wav 234496 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 10, 'audio': array([[ 1.05405816e-04],
#        [ 1.05405816e-04],
#        [ 1.05405816e-04],
#        ...,
#        [ 2.38683209e-01],
#        [-2.34459624e-01],
#        [ 1.55509293e-01]], dtype=float32), 'sr': 8000}
# 549 ../test_train_data/2017019740011_kimhyeryeong/1.wav 262144 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 10, 'audio': array([[-8.9959121e-06],
#        [-8.9959121e-06],
#        [-8.9959121e-06],
#        ...,
#        [ 1.4918529e-02],
#        [ 2.3031313e-02],
#        [ 3.0819587e-02]], dtype=float32), 'sr': 8000}
# 550 ../test_train_data/2017019740016_kangyeseo/5.wav 212470 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 15, 'audio': array([[-2.5499184e-04],
#        [-9.1181713e-04],
#        [-2.8126060e-03],
#        ...,
#        [-3.1429702e-01],
#        [ 7.7305757e-02],
#        [-1.1692423e-01]], dtype=float32), 'sr': 8000}
# 551 ../test_train_data/2017019740016_kangyeseo/4.wav 213323 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 15, 'audio': array([[-5.4929149e-04],
#        [-8.2532060e-04],
#        [-4.3557971e-04],
#        ...,
#        [ 1.7444085e+00],
#        [ 2.2526102e+00],
#        [ 2.9015684e+00]], dtype=float32), 'sr': 8000}
# 552 ../test_train_data/2017019740016_kangyeseo/3.wav 223051 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 15, 'audio': array([[-4.8629523e-04],
#        [-2.3499940e-04],
#        [-1.3863571e-03],
#        ...,
#        [ 3.4251663e-01],
#        [-1.9174776e-03],
#        [-3.4917855e-01]], dtype=float32), 'sr': 8000}
# 553 ../test_train_data/2017019740016_kangyeseo/2.wav 200694 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 15, 'audio': array([[-4.8111970e-04],
#        [-2.0892536e-03],
#        [-2.5656668e-03],
#        ...,
#        [-2.0780306e+00],
#        [-1.4784383e+00],
#        [-8.6792737e-01]], dtype=float32), 'sr': 8000}
# 554 ../test_train_data/2017019740016_kangyeseo/1.wav 217931 -0.0 0.9999998
# CUT New length = 10000
# -----------------
# {'class_id': 15, 'audio': array([[-0.00039387],
#        [-0.00028082],
#        [-0.00039702],
#        ...,
#        [ 0.00071634],
#        [ 0.03364844],
#        [ 0.05231305]], dtype=float32), 'sr': 8000}
# 555 ../test_train_data/2017019740015_choihayoung/5.wav 253600 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 14, 'audio': array([[8.5662125e-04],
#        [3.9564737e-04],
#        [1.8179026e-05],
#        ...,
#        [2.4923433e-01],
#        [1.8271451e-01],
#        [2.9802099e-01]], dtype=float32), 'sr': 8000}
# 556 ../test_train_data/2017019740015_choihayoung/4.wav 241483 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 14, 'audio': array([[-6.8799243e-04],
#        [ 1.4295131e-04],
#        [-3.2560283e-04],
#        ...,
#        [ 1.8280180e+00],
#        [ 1.3988780e+00],
#        [ 7.4336463e-01]], dtype=float32), 'sr': 8000}
# 557 ../test_train_data/2017019740015_choihayoung/3.wav 235851 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 14, 'audio': array([[ 1.5280139e-05],
#        [-9.9025892e-05],
#        [-1.2031889e-05],
#        ...,
#        [-5.6460345e-01],
#        [-1.2594031e-01],
#        [ 5.9645361e-01]], dtype=float32), 'sr': 8000}
# 558 ../test_train_data/2017019740015_choihayoung/2.wav 241142 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 14, 'audio': array([[ 3.8314841e-04],
#        [-5.2073557e-04],
#        [-6.9342041e-04],
#        ...,
#        [-2.3849740e+00],
#        [-2.3518696e+00],
#        [-2.5833044e+00]], dtype=float32), 'sr': 8000}
# 559 ../test_train_data/2017019740015_choihayoung/1.wav 225952 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 14, 'audio': array([[-1.1597269e-04],
#        [-1.7336455e-04],
#        [-2.7235318e-04],
#        ...,
#        [ 3.2365316e-01],
#        [ 7.4614149e-01],
#        [ 1.1011398e+00]], dtype=float32), 'sr': 8000}
# 560 ../test_train_data/2017019880034_leesujung/5.wav 241117 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 104, 'audio': array([[-6.7467081e-05],
#        [-6.7467081e-05],
#        [-6.7467081e-05],
#        ...,
#        [-3.3993644e-01],
#        [ 7.1047857e-02],
#        [ 1.5331511e-01]], dtype=float32), 'sr': 8000}
# 561 ../test_train_data/2017019880034_leesujung/4.wav 255048 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 104, 'audio': array([[ 5.3766144e-05],
#        [ 5.3766144e-05],
#        [ 5.3766144e-05],
#        ...,
#        [-5.1574543e-02],
#        [ 3.6382511e-02],
#        [-2.6312878e-02]], dtype=float32), 'sr': 8000}
# 562 ../test_train_data/2017019880034_leesujung/3.wav 244274 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 104, 'audio': array([[ 5.3441709e-05],
#        [ 5.3441709e-05],
#        [ 5.3441709e-05],
#        ...,
#        [ 2.5816567e-02],
#        [ 6.2092673e-03],
#        [-1.5653376e-02]], dtype=float32), 'sr': 8000}
# 563 ../test_train_data/2017019880034_leesujung/2.wav 238702 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 104, 'audio': array([[-1.3162822e-05],
#        [-1.3162822e-05],
#        [-1.3162822e-05],
#        ...,
#        [-4.2882352e+00],
#        [-2.2537372e+00],
#        [ 1.5676625e-01]], dtype=float32), 'sr': 8000}
# 564 ../test_train_data/2017019880034_leesujung/1.wav 258949 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 104, 'audio': array([[ 3.2470445e-05],
#        [ 3.2470445e-05],
#        [ 3.2470445e-05],
#        ...,
#        [-7.4474134e-02],
#        [-7.9698592e-02],
#        [-7.3670566e-02]], dtype=float32), 'sr': 8000}
# 565 ../test_train_data/2017019770024_chuminha/5.wav 195923 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 54, 'audio': array([[-0.00362287],
#        [ 0.05711015],
#        [ 0.09004832],
#        ...,
#        [ 0.39539042],
#        [ 0.5713655 ],
#        [ 0.66192734]], dtype=float32), 'sr': 8000}
# 566 ../test_train_data/2017019770024_chuminha/4.wav 197466 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 54, 'audio': array([[-0.02027981],
#        [-0.03703588],
#        [-0.03136551],
#        ...,
#        [-1.5456696 ],
#        [-1.6479459 ],
#        [-1.9934654 ]], dtype=float32), 'sr': 8000}
# 567 ../test_train_data/2017019770024_chuminha/3.wav 210394 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 54, 'audio': array([[ 0.00671642],
#        [ 0.01134765],
#        [-0.004527  ],
#        ...,
#        [-0.28592327],
#        [-0.2289049 ],
#        [-0.15424785]], dtype=float32), 'sr': 8000}
# 568 ../test_train_data/2017019770024_chuminha/2.wav 219890 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 54, 'audio': array([[0.0291281 ],
#        [0.04589947],
#        [0.04461647],
#        ...,
#        [0.08061727],
#        [0.04257799],
#        [0.05532416]], dtype=float32), 'sr': 8000}
# 569 ../test_train_data/2017019770024_chuminha/1.wav 232980 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 54, 'audio': array([[ 0.04777558],
#        [ 0.00417622],
#        [-0.07946019],
#        ...,
#        [-0.02861677],
#        [-0.03014874],
#        [-0.03061185]], dtype=float32), 'sr': 8000}
# 570 ../test_train_data/2017019880003_kimminji/5.wav 237773 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 73, 'audio': array([[-1.6936821e-05],
#        [-1.6936821e-05],
#        [-1.6936821e-05],
#        ...,
#        [ 7.6709859e-02],
#        [-1.0205222e-01],
#        [ 1.7637163e-01]], dtype=float32), 'sr': 8000}
# 571 ../test_train_data/2017019880003_kimminji/4.wav 237587 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 73, 'audio': array([[2.3234405e-05],
#        [2.3234405e-05],
#        [2.3234405e-05],
#        ...,
#        [1.7778188e-01],
#        [2.0964967e-01],
#        [1.8193583e-01]], dtype=float32), 'sr': 8000}
# 572 ../test_train_data/2017019880003_kimminji/3.wav 247618 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 73, 'audio': array([[-4.3675383e-05],
#        [-4.3675383e-05],
#        [-4.3675383e-05],
#        ...,
#        [-2.5746478e-03],
#        [-3.4014254e-03],
#        [-6.5095113e-03]], dtype=float32), 'sr': 8000}
# 573 ../test_train_data/2017019880003_kimminji/2.wav 236101 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 73, 'audio': array([[-9.8529954e-06],
#        [-9.8529954e-06],
#        [-9.8529954e-06],
#        ...,
#        [ 1.7512474e-02],
#        [ 1.6253712e-02],
#        [ 1.2183476e-02]], dtype=float32), 'sr': 8000}
# 574 ../test_train_data/2017019880003_kimminji/1.wav 232200 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 73, 'audio': array([[-4.6322759e-05],
#        [-4.6322759e-05],
#        [-4.6322759e-05],
#        ...,
#        [-2.8866398e-01],
#        [-9.0241171e-02],
#        [-2.2294989e-01]], dtype=float32), 'sr': 8000}

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Lambda
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow import convert_to_tensor
import numpy as np
import pickle
import os
from glob import glob

# AUDIO_LENGTH = 200000
OUTPUT_DIR = './output'
OUTPUT_DIR_TRAIN = os.path.join(OUTPUT_DIR, 'train')
OUTPUT_DIR_TEST = os.path.join(OUTPUT_DIR, 'test')

DATA_AUDIO_DIR = '../test_train_data'
list_dir = os.listdir(DATA_AUDIO_DIR)
list_dir.sort()
# TARGET_SR = 16000

class_ids = {list_dir[i]: i for i in range(len(list_dir))}
def m5(num_classes):
    print("!!!!!!!!", num_classes)
    print('Using Model M5')
    m = Sequential()
    m.add(Conv1D(128,
                 input_shape=[AUDIO_LENGTH, 1],
                 kernel_size=80,
                 strides=4,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(128,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(256,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Conv1D(512,
                 kernel_size=3,
                 strides=1,
                 padding='same',
                 kernel_initializer='glorot_uniform',
                 kernel_regularizer=regularizers.l2(l=0.0001)))
    m.add(BatchNormalization())
    m.add(Activation('relu'))
    m.add(MaxPooling1D(pool_size=4, strides=None))
    m.add(Lambda(lambda x: K.mean(x, axis=1)))  # Same as GAP for 1D Conv Layer
    m.add(Dense(num_classes, activation='softmax'))
    return m


def get_data(file_list):
    def load_into(_filename, _x, _y):
#         print("**** : ", _filename)
#         print("~`~` : ", _filename[15:-6])
        
        with open(_filename, 'rb') as f:
            audio_element = pickle.load(f)
            _x.append(audio_element['audio'])
            _y.append(int(audio_element['class_id']))

    x, y = [], []
    for filename in file_list:
#         print("Predict file name : ", filename)
        load_into(filename, x, y)
    return np.array(x), np.array(y)
#     return x, y




num_classes = len(list_dir)
print(num_classes)
model = m5(num_classes=len(list_dir))

if model is None:
    exit('Something went wrong!!')

model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
print(model.summary())

train_files = glob(os.path.join(OUTPUT_DIR_TRAIN, '**.pkl'))
x_tr, y_tr = get_data(train_files)
# print(len(x_tr))
# print(y_tr)
y_tr = to_categorical(y_tr, num_classes=num_classes)

test_files = glob(os.path.join(OUTPUT_DIR_TEST, '**.pkl'))
x_te, y_te = get_data(test_files)
y_te = to_categorical(y_te, num_classes=num_classes)

print('x_tr.shape =', x_tr.shape)
print('y_tr.shape =', y_tr.shape)
print('x_te.shape =', x_te.shape)
print('y_te.shape =', y_te.shape)
print(type(x_te))

# if the accuracy does not increase over 10 epochs, reduce the learning rate by half.
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=10, min_lr=0.00005, verbose=1)
batch_size = 128
history = model.fit(x=x_tr, y=y_tr, batch_size=16, epochs=100, verbose=2, shuffle=True, validation_data=(x_te, y_te), callbacks=[reduce_lr])
    
# epoch 500 audio_length 10000 min_lr 0.0001 sr 8000 batch_size 16 : val_acc 0.73
# epoch 500 audio_length 10000 min_lr 0.00005 sr 8000 batch_size 16 : val_acc 0.77(0.83)
# epoch 50 audio_length 20000 min_lr 0.00005 sr 8000 batch_size 16 : val_acc 0.90
# epoch 100 audio_length 20000 min_lr 0.00005 sr 8000 batch_size 16 : val_acc 0.93
# epoch 100 audio_length 20000 min_lr 0.00005 sr 8000 batch_size 32 : val_acc 0.89(0.90) predict 0.75
# epoch 150 audio_length 20000 min_lr 0.00005 sr 8000 batch_size 16 : val_acc 0.91 predict 0.75
# Out:
# 115
# !!!!!!!! 115
# Using Model M5
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_8 (Conv1D)            (None, 2500, 128)         10368
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2500, 128)         512
# _________________________________________________________________
# activation_8 (Activation)    (None, 2500, 128)         0
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 625, 128)          0
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 625, 128)          49280
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 625, 128)          512
# _________________________________________________________________
# activation_9 (Activation)    (None, 625, 128)          0
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 156, 128)          0
# _________________________________________________________________
# conv1d_10 (Conv1D)           (None, 156, 256)          98560
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 156, 256)          1024
# _________________________________________________________________
# activation_10 (Activation)   (None, 156, 256)          0
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 39, 256)           0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 39, 512)           393728
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 39, 512)           2048
# _________________________________________________________________
# activation_11 (Activation)   (None, 39, 512)           0
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 9, 512)            0
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 115)               58995
# =================================================================
# Total params: 615,027
# Trainable params: 612,979
# Non-trainable params: 2,048
# _________________________________________________________________
# None
# x_tr.shape = (460, 10000, 1)
# y_tr.shape = (460, 115)
# x_te.shape = (115, 10000, 1)
# y_te.shape = (115, 115)
# <class 'numpy.ndarray'>
# Train on 460 samples, validate on 115 samples
# Epoch 1/100
# 460/460 - 1s - loss: 5.2108 - accuracy: 0.0174 - val_loss: 4.6795 - val_accuracy: 0.0435
# Epoch 2/100
# 460/460 - 0s - loss: 4.2718 - accuracy: 0.0652 - val_loss: 4.6924 - val_accuracy: 0.0348
# Epoch 3/100
# 460/460 - 0s - loss: 3.9641 - accuracy: 0.1043 - val_loss: 4.7468 - val_accuracy: 0.0087
# Epoch 4/100
# 460/460 - 0s - loss: 3.7805 - accuracy: 0.1565 - val_loss: 4.8209 - val_accuracy: 0.0261
# Epoch 5/100
# 460/460 - 0s - loss: 3.4823 - accuracy: 0.1913 - val_loss: 4.8178 - val_accuracy: 0.0348
# Epoch 6/100
# 460/460 - 0s - loss: 3.2454 - accuracy: 0.3000 - val_loss: 4.9778 - val_accuracy: 0.0261
# Epoch 7/100
# 460/460 - 0s - loss: 3.0405 - accuracy: 0.3196 - val_loss: 4.7387 - val_accuracy: 0.0696
# Epoch 8/100
# 460/460 - 0s - loss: 2.7712 - accuracy: 0.4087 - val_loss: 4.3194 - val_accuracy: 0.1304
# Epoch 9/100
# 460/460 - 0s - loss: 2.6460 - accuracy: 0.3935 - val_loss: 3.9593 - val_accuracy: 0.1565
# Epoch 10/100
# 460/460 - 0s - loss: 2.4173 - accuracy: 0.4804 - val_loss: 3.7659 - val_accuracy: 0.1739
# Epoch 11/100
# 460/460 - 0s - loss: 2.3318 - accuracy: 0.4804 - val_loss: 3.6508 - val_accuracy: 0.2087
# Epoch 12/100
# 460/460 - 0s - loss: 2.2158 - accuracy: 0.4957 - val_loss: 3.3750 - val_accuracy: 0.2783
# Epoch 13/100
# 460/460 - 0s - loss: 2.0396 - accuracy: 0.5457 - val_loss: 3.5508 - val_accuracy: 0.2435
# Epoch 14/100
# 460/460 - 0s - loss: 1.9355 - accuracy: 0.5761 - val_loss: 3.6050 - val_accuracy: 0.1913
# Epoch 15/100
# 460/460 - 0s - loss: 1.7587 - accuracy: 0.6370 - val_loss: 3.1702 - val_accuracy: 0.2609
# Epoch 16/100
# 460/460 - 0s - loss: 1.6681 - accuracy: 0.6500 - val_loss: 3.3621 - val_accuracy: 0.2522
# Epoch 17/100
# 460/460 - 0s - loss: 1.5716 - accuracy: 0.6391 - val_loss: 3.4629 - val_accuracy: 0.2522
# Epoch 18/100
# 460/460 - 0s - loss: 1.4972 - accuracy: 0.6761 - val_loss: 4.3874 - val_accuracy: 0.2000
# Epoch 19/100
# 460/460 - 0s - loss: 1.4372 - accuracy: 0.6804 - val_loss: 3.8357 - val_accuracy: 0.2522
# Epoch 20/100
# 460/460 - 0s - loss: 1.2741 - accuracy: 0.7174 - val_loss: 3.4967 - val_accuracy: 0.2870
# Epoch 21/100
# 460/460 - 0s - loss: 1.2508 - accuracy: 0.7457 - val_loss: 3.0699 - val_accuracy: 0.2783
# Epoch 22/100
# 460/460 - 0s - loss: 1.2429 - accuracy: 0.7304 - val_loss: 2.9300 - val_accuracy: 0.3652
# Epoch 23/100
# 460/460 - 0s - loss: 1.2257 - accuracy: 0.7500 - val_loss: 3.6450 - val_accuracy: 0.2609
# Epoch 24/100
# 460/460 - 0s - loss: 1.0889 - accuracy: 0.7717 - val_loss: 3.6924 - val_accuracy: 0.2696
# Epoch 25/100
# 460/460 - 0s - loss: 1.1010 - accuracy: 0.7609 - val_loss: 3.5846 - val_accuracy: 0.3739
# Epoch 26/100
# 460/460 - 0s - loss: 1.0568 - accuracy: 0.7739 - val_loss: 2.4913 - val_accuracy: 0.4261
# Epoch 27/100
# 460/460 - 0s - loss: 0.9732 - accuracy: 0.8000 - val_loss: 5.2633 - val_accuracy: 0.1652
# Epoch 28/100
# 460/460 - 1s - loss: 0.8898 - accuracy: 0.8217 - val_loss: 3.8395 - val_accuracy: 0.3478
# Epoch 29/100
# 460/460 - 0s - loss: 0.8465 - accuracy: 0.8174 - val_loss: 3.2774 - val_accuracy: 0.2957
# Epoch 30/100
# 460/460 - 0s - loss: 0.8379 - accuracy: 0.8174 - val_loss: 2.2724 - val_accuracy: 0.4870
# Epoch 31/100
# 460/460 - 0s - loss: 0.7775 - accuracy: 0.8000 - val_loss: 2.5343 - val_accuracy: 0.4522
# Epoch 32/100
# 460/460 - 0s - loss: 0.7783 - accuracy: 0.8174 - val_loss: 3.1528 - val_accuracy: 0.3130
# Epoch 33/100
# 460/460 - 0s - loss: 0.7306 - accuracy: 0.8413 - val_loss: 3.1563 - val_accuracy: 0.4348
# Epoch 34/100
# 460/460 - 0s - loss: 0.7326 - accuracy: 0.8283 - val_loss: 2.5117 - val_accuracy: 0.4087
# Epoch 35/100
# 460/460 - 0s - loss: 0.6844 - accuracy: 0.8370 - val_loss: 2.3374 - val_accuracy: 0.4957
# Epoch 36/100
# 460/460 - 0s - loss: 0.6802 - accuracy: 0.8500 - val_loss: 3.8014 - val_accuracy: 0.3826
# Epoch 37/100
# 460/460 - 0s - loss: 0.7095 - accuracy: 0.8522 - val_loss: 3.3596 - val_accuracy: 0.4174
# Epoch 38/100
# 460/460 - 0s - loss: 0.6967 - accuracy: 0.8478 - val_loss: 2.4204 - val_accuracy: 0.4435
# Epoch 39/100
# 460/460 - 0s - loss: 0.6367 - accuracy: 0.8457 - val_loss: 3.9593 - val_accuracy: 0.3652
# Epoch 40/100
# 460/460 - 0s - loss: 0.6244 - accuracy: 0.8543 - val_loss: 2.1879 - val_accuracy: 0.4435
# Epoch 41/100
# 460/460 - 0s - loss: 0.5840 - accuracy: 0.8848 - val_loss: 2.3808 - val_accuracy: 0.5391
# Epoch 42/100
# 460/460 - 0s - loss: 0.5743 - accuracy: 0.8630 - val_loss: 2.6074 - val_accuracy: 0.4174
# Epoch 43/100
# 460/460 - 0s - loss: 0.5523 - accuracy: 0.8717 - val_loss: 2.7245 - val_accuracy: 0.4348
# Epoch 44/100
# 460/460 - 1s - loss: 0.5289 - accuracy: 0.8870 - val_loss: 1.9410 - val_accuracy: 0.5565
# Epoch 45/100
# 460/460 - 0s - loss: 0.5282 - accuracy: 0.8804 - val_loss: 3.2745 - val_accuracy: 0.3739
# Epoch 46/100
# 460/460 - 0s - loss: 0.5098 - accuracy: 0.8957 - val_loss: 2.2396 - val_accuracy: 0.5652
# Epoch 47/100
# 460/460 - 0s - loss: 0.4510 - accuracy: 0.9065 - val_loss: 1.9138 - val_accuracy: 0.5913
# Epoch 48/100
# 460/460 - 0s - loss: 0.4336 - accuracy: 0.9130 - val_loss: 2.7122 - val_accuracy: 0.5217
# Epoch 49/100
# 460/460 - 0s - loss: 0.4457 - accuracy: 0.9130 - val_loss: 2.3174 - val_accuracy: 0.5565
# Epoch 50/100
# 460/460 - 0s - loss: 0.5030 - accuracy: 0.8783 - val_loss: 2.1315 - val_accuracy: 0.5478
# Epoch 51/100
# 460/460 - 0s - loss: 0.4309 - accuracy: 0.9043 - val_loss: 1.9276 - val_accuracy: 0.5739
# Epoch 52/100
# 460/460 - 0s - loss: 0.4245 - accuracy: 0.9239 - val_loss: 2.4341 - val_accuracy: 0.5043
# Epoch 53/100
# 460/460 - 0s - loss: 0.4673 - accuracy: 0.9109 - val_loss: 1.9066 - val_accuracy: 0.5826
# Epoch 54/100
# 460/460 - 0s - loss: 0.4231 - accuracy: 0.9174 - val_loss: 2.1287 - val_accuracy: 0.5304
# Epoch 55/100
# 460/460 - 0s - loss: 0.3645 - accuracy: 0.9348 - val_loss: 2.1794 - val_accuracy: 0.5565
# Epoch 56/100
# 460/460 - 0s - loss: 0.3845 - accuracy: 0.9152 - val_loss: 2.3546 - val_accuracy: 0.5130
# Epoch 57/100
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 460/460 - 0s - loss: 0.3630 - accuracy: 0.9261 - val_loss: 2.0920 - val_accuracy: 0.5739
# Epoch 58/100
# 460/460 - 0s - loss: 0.3108 - accuracy: 0.9522 - val_loss: 1.6441 - val_accuracy: 0.6522
# Epoch 59/100
# 460/460 - 0s - loss: 0.2943 - accuracy: 0.9500 - val_loss: 1.6932 - val_accuracy: 0.6087
# Epoch 60/100
# 460/460 - 0s - loss: 0.2831 - accuracy: 0.9522 - val_loss: 1.6318 - val_accuracy: 0.6609
# Epoch 61/100
# 460/460 - 0s - loss: 0.2682 - accuracy: 0.9500 - val_loss: 1.7707 - val_accuracy: 0.6174
# Epoch 62/100
# 460/460 - 0s - loss: 0.2739 - accuracy: 0.9522 - val_loss: 1.6730 - val_accuracy: 0.6087
# Epoch 63/100
# 460/460 - 0s - loss: 0.2594 - accuracy: 0.9630 - val_loss: 1.4401 - val_accuracy: 0.6870
# Epoch 64/100
# 460/460 - 0s - loss: 0.2449 - accuracy: 0.9565 - val_loss: 1.4117 - val_accuracy: 0.6957
# Epoch 65/100
# 460/460 - 0s - loss: 0.2521 - accuracy: 0.9522 - val_loss: 1.6859 - val_accuracy: 0.6261
# Epoch 66/100
# 460/460 - 0s - loss: 0.2464 - accuracy: 0.9674 - val_loss: 1.4050 - val_accuracy: 0.6870
# Epoch 67/100
# 460/460 - 0s - loss: 0.2590 - accuracy: 0.9587 - val_loss: 1.5937 - val_accuracy: 0.6174
# Epoch 68/100
# 460/460 - 0s - loss: 0.2631 - accuracy: 0.9587 - val_loss: 1.9084 - val_accuracy: 0.6000
# Epoch 69/100
# 460/460 - 0s - loss: 0.2483 - accuracy: 0.9543 - val_loss: 1.4809 - val_accuracy: 0.6609
# Epoch 70/100
# 460/460 - 1s - loss: 0.2456 - accuracy: 0.9587 - val_loss: 1.7093 - val_accuracy: 0.6261
# Epoch 71/100
# 460/460 - 1s - loss: 0.2656 - accuracy: 0.9457 - val_loss: 1.4465 - val_accuracy: 0.6696
# Epoch 72/100
# 460/460 - 0s - loss: 0.2666 - accuracy: 0.9587 - val_loss: 2.7682 - val_accuracy: 0.4261
# Epoch 73/100
# 460/460 - 0s - loss: 0.2358 - accuracy: 0.9652 - val_loss: 2.2585 - val_accuracy: 0.5826
# Epoch 74/100
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 460/460 - 0s - loss: 0.2342 - accuracy: 0.9674 - val_loss: 1.5869 - val_accuracy: 0.6609
# Epoch 75/100
# 460/460 - 0s - loss: 0.2009 - accuracy: 0.9739 - val_loss: 1.2800 - val_accuracy: 0.7043
# Epoch 76/100
# 460/460 - 0s - loss: 0.2098 - accuracy: 0.9674 - val_loss: 1.2894 - val_accuracy: 0.6957
# Epoch 77/100
# 460/460 - 0s - loss: 0.2036 - accuracy: 0.9652 - val_loss: 1.3643 - val_accuracy: 0.7130
# Epoch 78/100
# 460/460 - 0s - loss: 0.2099 - accuracy: 0.9652 - val_loss: 1.3054 - val_accuracy: 0.7217
# Epoch 79/100
# 460/460 - 0s - loss: 0.1843 - accuracy: 0.9761 - val_loss: 1.3736 - val_accuracy: 0.6870
# Epoch 80/100
# 460/460 - 0s - loss: 0.2058 - accuracy: 0.9783 - val_loss: 1.2670 - val_accuracy: 0.7304
# Epoch 81/100
# 460/460 - 0s - loss: 0.2021 - accuracy: 0.9761 - val_loss: 1.3642 - val_accuracy: 0.6870
# Epoch 82/100
# 460/460 - 0s - loss: 0.2138 - accuracy: 0.9674 - val_loss: 1.3551 - val_accuracy: 0.6783
# Epoch 83/100
# 460/460 - 0s - loss: 0.2023 - accuracy: 0.9717 - val_loss: 1.2110 - val_accuracy: 0.7304
# Epoch 84/100
# 460/460 - 0s - loss: 0.2038 - accuracy: 0.9652 - val_loss: 1.2292 - val_accuracy: 0.7217
# Epoch 85/100
# 460/460 - 0s - loss: 0.1914 - accuracy: 0.9783 - val_loss: 1.2119 - val_accuracy: 0.7304
# Epoch 86/100
# 460/460 - 0s - loss: 0.1977 - accuracy: 0.9630 - val_loss: 1.3057 - val_accuracy: 0.7043
# Epoch 87/100
# 460/460 - 0s - loss: 0.1993 - accuracy: 0.9783 - val_loss: 1.2934 - val_accuracy: 0.7391
# Epoch 88/100
# 460/460 - 0s - loss: 0.1886 - accuracy: 0.9739 - val_loss: 1.2686 - val_accuracy: 0.7217
# Epoch 89/100
# 460/460 - 0s - loss: 0.1897 - accuracy: 0.9717 - val_loss: 1.1087 - val_accuracy: 0.7652
# Epoch 90/100
# 460/460 - 0s - loss: 0.1922 - accuracy: 0.9630 - val_loss: 1.2674 - val_accuracy: 0.7304
# Epoch 91/100
# 460/460 - 0s - loss: 0.1982 - accuracy: 0.9543 - val_loss: 1.2503 - val_accuracy: 0.7217
# Epoch 92/100
# 460/460 - 0s - loss: 0.1785 - accuracy: 0.9761 - val_loss: 1.3556 - val_accuracy: 0.7043
# Epoch 93/100
# 460/460 - 0s - loss: 0.2014 - accuracy: 0.9717 - val_loss: 1.3273 - val_accuracy: 0.7043
# Epoch 94/100
# 460/460 - 0s - loss: 0.1861 - accuracy: 0.9739 - val_loss: 1.3187 - val_accuracy: 0.7043
# Epoch 95/100
# 460/460 - 0s - loss: 0.1784 - accuracy: 0.9739 - val_loss: 1.3535 - val_accuracy: 0.6957
# Epoch 96/100
# 460/460 - 0s - loss: 0.1801 - accuracy: 0.9783 - val_loss: 1.3556 - val_accuracy: 0.6870
# Epoch 97/100
# 460/460 - 0s - loss: 0.1938 - accuracy: 0.9674 - val_loss: 1.4741 - val_accuracy: 0.6696
# Epoch 98/100
# 460/460 - 0s - loss: 0.1886 - accuracy: 0.9696 - val_loss: 1.3654 - val_accuracy: 0.7217
# Epoch 99/100
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 460/460 - 0s - loss: 0.1724 - accuracy: 0.9783 - val_loss: 1.2636 - val_accuracy: 0.7130
# Epoch 100/100
# 460/460 - 0s - loss: 0.1765 - accuracy: 0.9696 - val_loss: 1.1706 - val_accuracy: 0.7391

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 6))
plt.rc('font', size=18)

plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train_accuracy", "val_accuracy"])
plt.show()

# %%
import pickle
from glob import iglob
import numpy as np
import librosa
from shutil import rmtree
from constants import *
from constants import DATA_AUDIO_DIR
DATA_AUDIO_VAL_DIR = '../test_val_data'
OUTPUT_DIR_VAL_TRAIN = './output_val/train'
OUTPUT_DIR_VAL_TEST = './output_val/test'

DATA_AUDIO_DIR = '../test_train_data'
list_dir = os.listdir(DATA_AUDIO_DIR)
list_dir.sort()

def mkdir_p(path):
    import errno
    try:
        os.makedirs(path)
    except OSError as exc:
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else:
            raise


# def del_folder(path):
#     try:
#         rmtree(path)
#     except:
#         pass


# del_folder(OUTPUT_DIR_TRAIN)
# del_folder(OUTPUT_DIR_TEST)
mkdir_p(OUTPUT_DIR_TRAIN)
mkdir_p(OUTPUT_DIR_TEST)

class_id = {list_dir[i]: i for i in range(len(list_dir))}


def extract_class_id(wav_filename):
    return class_ids.get(wav_filename[17:-6])


def read_audio_from_filename(filename, target_sr):
    audio, _ = librosa.load(filename, sr=target_sr, mono=True)
    audio = audio.reshape(-1, 1)
    return audio


def convert_data():
    DATA_AUDIO_DIR = '../test_train_data'
    list_dir = os.listdir(DATA_AUDIO_VAL_DIR)
    list_dir.sort()
    TARGET_SR = 8000
    print(list_dir)
#     AUDIO_LENGTH = 200000
#     TARGET_SR = 16000
    for i, wav_filename in enumerate(iglob(os.path.join(DATA_AUDIO_VAL_DIR, '**/**.wav'), recursive=True)):
        print(i, wav_filename)
        class_id = extract_class_id(wav_filename)
        audio_buf = read_audio_from_filename(wav_filename, target_sr=TARGET_SR)
        # normalize mean 0, variance 1
        audio_buf = (audio_buf - np.mean(audio_buf)) / np.std(audio_buf)
        original_length = len(audio_buf)
        print(i, wav_filename, original_length, np.round(np.mean(audio_buf), 4), np.std(audio_buf))
        if original_length < AUDIO_LENGTH:
            audio_buf = np.concatenate((audio_buf, np.zeros(shape=(AUDIO_LENGTH - original_length, 1))))
            print('PAD New length =', len(audio_buf))
        elif original_length > AUDIO_LENGTH:
            audio_buf = audio_buf[0:AUDIO_LENGTH]
#             audio_buf = audio_buf[10000:AUDIO_LENGTH+10000]
            print('CUT New length =', len(audio_buf))

        output_folder = OUTPUT_DIR_VAL_TRAIN
#         if i % 5 == 0:
#             output_folder = OUTPUT_DIR_VAL_TEST

        output_filename = os.path.join(output_folder, str(wav_filename[17:-4]).replace('/', '_') + '.pkl')

        out = {'class_id': class_id,
               'audio': audio_buf,
               'sr': TARGET_SR}
        print("-----------------")
        print(out)
        with open(output_filename, 'wb') as w:
            pickle.dump(out, w)


if __name__ == '__main__':
    convert_data()
# Out:
# ['2017019740001_kwakjuheon', '2017019740029_limdonggeun', '2017019770001_kwonyuna', '2017019880001_kimsubin']
# 0 ../test_val_data/2017019880001_kimsubin/5.wav
# 0 ../test_val_data/2017019880001_kimsubin/5.wav 176844 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[ 4.8197612e-06],
#        [ 4.8197612e-06],
#        [ 4.8197612e-06],
#        ...,
#        [-4.0558866e-01],
#        [-2.9563633e-01],
#        [-2.2197224e-01]], dtype=float32), 'sr': 8000}
# 1 ../test_val_data/2017019880001_kimsubin/4.wav
# 1 ../test_val_data/2017019880001_kimsubin/4.wav 175915 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[-9.4105644e-06],
#        [-9.4105644e-06],
#        [-9.4105644e-06],
#        ...,
#        [-7.4374503e-01],
#        [-6.9286388e-01],
#        [-4.0462705e-01]], dtype=float32), 'sr': 8000}
# 2 ../test_val_data/2017019880001_kimsubin/3.wav
# 2 ../test_val_data/2017019880001_kimsubin/3.wav 174615 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[-3.2709155e-05],
#        [-3.2709155e-05],
#        [-3.2709155e-05],
#        ...,
#        [-6.5562862e-01],
#        [-4.2519107e-01],
#        [-2.0614362e-01]], dtype=float32), 'sr': 8000}
# 3 ../test_val_data/2017019880001_kimsubin/2.wav
# 3 ../test_val_data/2017019880001_kimsubin/2.wav 178701 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[ 1.8725807e-05],
#        [ 1.8725807e-05],
#        [ 1.8725807e-05],
#        ...,
#        [-7.8624897e-03],
#        [-1.6080941e+00],
#        [-2.7896507e+00]], dtype=float32), 'sr': 8000}
# 4 ../test_val_data/2017019880001_kimsubin/1.wav
# 4 ../test_val_data/2017019880001_kimsubin/1.wav 183531 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 71, 'audio': array([[ 4.3873682e-09],
#        [ 4.3873682e-09],
#        [ 4.3873682e-09],
#        ...,
#        [ 2.2608428e-01],
#        [-3.6653501e-01],
#        [-1.0313274e+00]], dtype=float32), 'sr': 8000}
# 5 ../test_val_data/2017019740029_limdonggeun/1.wav
# 5 ../test_val_data/2017019740029_limdonggeun/1.wav 187723 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 28, 'audio': array([[-0.0013528 ],
#        [ 0.00088633],
#        [-0.00219865],
#        ...,
#        [ 0.01661557],
#        [-0.01513909],
#        [-0.0196343 ]], dtype=float32), 'sr': 8000}
# 6 ../test_val_data/2017019770001_kwonyuna/5.wav
# 6 ../test_val_data/2017019770001_kwonyuna/5.wav 187894 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 31, 'audio': array([[ 3.55772179e-04],
#        [ 7.31984983e-05],
#        [ 8.07423028e-04],
#        ...,
#        [ 1.05260625e-01],
#        [ 1.39604703e-01],
#        [-3.41630965e-01]], dtype=float32), 'sr': 8000}
# 7 ../test_val_data/2017019770001_kwonyuna/4.wav
# 7 ../test_val_data/2017019770001_kwonyuna/4.wav 194720 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 31, 'audio': array([[ 3.6147019e-04],
#        [ 1.3493781e-04],
#        [ 7.8823778e-04],
#        ...,
#        [ 9.3784636e-01],
#        [ 3.5268191e-01],
#        [-1.9064921e-01]], dtype=float32), 'sr': 8000}
# 8 ../test_val_data/2017019770001_kwonyuna/3.wav
# 8 ../test_val_data/2017019770001_kwonyuna/3.wav 201206 0.0 1.0000001
# CUT New length = 10000
# -----------------
# {'class_id': 31, 'audio': array([[3.1074413e-04],
#        [3.9338085e-04],
#        [8.2514458e-04],
#        ...,
#        [6.2587178e-01],
#        [4.4405007e-01],
#        [2.7376968e-01]], dtype=float32), 'sr': 8000}
# 9 ../test_val_data/2017019770001_kwonyuna/2.wav
# 9 ../test_val_data/2017019770001_kwonyuna/2.wav 203254 -0.0 0.9999999
# CUT New length = 10000
# -----------------
# {'class_id': 31, 'audio': array([[ 0.00042234],
#        [ 0.00038967],
#        [ 0.00079258],
#        ...,
#        [ 0.00147722],
#        [-0.01283487],
#        [-0.01601032]], dtype=float32), 'sr': 8000}
# 10 ../test_val_data/2017019770001_kwonyuna/1.wav
# 10 ../test_val_data/2017019770001_kwonyuna/1.wav 210080 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 31, 'audio': array([[ 3.6729407e-04],
#        [ 8.3726802e-05],
#        [ 4.1892932e-04],
#        ...,
#        [-3.1862408e-02],
#        [-1.1211376e-01],
#        [ 9.6300475e-02]], dtype=float32), 'sr': 8000}
# 11 ../test_val_data/2017019740001_kwakjuheon/5.wav
# 11 ../test_val_data/2017019740001_kwakjuheon/5.wav 196427 -0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 0, 'audio': array([[-0.0005319 ],
#        [ 0.00047966],
#        [-0.00022631],
#        ...,
#        [ 0.03036995],
#        [ 0.00586147],
#        [ 0.02229753]], dtype=float32), 'sr': 8000}
# 12 ../test_val_data/2017019740001_kwakjuheon/4.wav
# 12 ../test_val_data/2017019740001_kwakjuheon/4.wav 207008 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 0, 'audio': array([[ 1.5895051e-04],
#        [ 4.7673270e-04],
#        [-5.0388690e-04],
#        ...,
#        [ 4.1391516e-01],
#        [ 9.4439656e-01],
#        [ 1.1150467e+00]], dtype=float32), 'sr': 8000}
# 13 ../test_val_data/2017019740001_kwakjuheon/3.wav
# 13 ../test_val_data/2017019740001_kwakjuheon/3.wav 212470 0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 0, 'audio': array([[2.5333435e-04],
#        [6.4627331e-04],
#        [2.2229107e-04],
#        ...,
#        [1.8267545e-01],
#        [4.5890257e-01],
#        [3.7230125e-01]], dtype=float32), 'sr': 8000}
# 14 ../test_val_data/2017019740001_kwakjuheon/2.wav
# 14 ../test_val_data/2017019740001_kwakjuheon/2.wav 212811 0.0 1.0
# CUT New length = 10000
# -----------------
# {'class_id': 0, 'audio': array([[ 1.72487678e-04],
#        [-1.07626336e-04],
#        [-8.57293780e-05],
#        ...,
#        [ 3.91131133e-01],
#        [ 3.27344239e-01],
#        [ 3.26232880e-01]], dtype=float32), 'sr': 8000}
# 15 ../test_val_data/2017019740001_kwakjuheon/1.wav
# 15 ../test_val_data/2017019740001_kwakjuheon/1.wav 209739 -0.0 0.99999994
# CUT New length = 10000
# -----------------
# {'class_id': 0, 'audio': array([[-6.5757299e-04],
#        [ 2.2923804e-03],
#        [ 2.1187332e-03],
#        ...,
#        [-1.2875361e+00],
#        [-1.2090256e+00],
#        [-1.0996408e+00]], dtype=float32), 'sr': 8000}

# %%
from sklearn.metrics import accuracy_score

train_files_1 = glob(os.path.join(OUTPUT_DIR_VAL_TRAIN, '**.pkl'))
train_files_1.sort()
# print(train_files_1)

x_tr_1, y_tr_1 = get_data(train_files_1)
# print('x_tr_1 : ', x_tr_1)
print('y_tr_1 : ', y_tr_1)

y_tr_12 = to_categorical(y_tr_1, num_classes=num_classes)
# print('y_tr_1 : ', y_tr_1)

pred_out = model.predict(x_tr_1)
# print('pred out : ', pred_out)

real =[]
pred_out_idex=[]

val_class_names = os.listdir(DATA_AUDIO_VAL_DIR)
print(val_class_names)
# val_class_names.sort()

DATA_AUDIO_DIR = '../test_train_data'
list_dir = os.listdir(DATA_AUDIO_DIR)
list_dir.sort()

j = 0
for i,pred in zip(range(0, len(pred_out)), pred_out) :
#     print('i : ', i)
#     print('pred : ', pred)
    print("pre : ", np.argmax(pred))
    if i == 5:
        j += 1
    print("Predict :",list_dir[np.argmax(pred)], ", Real :", list_dir[y_tr_1[i]])
    real.append(list_dir.index(list_dir[y_tr_1[i]]))
    pred_out_idex.append(np.argmax(pred))
    
# get the accuracy
print (accuracy_score(real, pred_out_idex))
# Out:
# y_tr_1 :  [ 0  0  0  0  0 28 31 31 31 31 31 71 71 71 71 71]
# ['2017019880001_kimsubin', '2017019740029_limdonggeun', '2017019770001_kwonyuna', '2017019740001_kwakjuheon']
# pre :  0
# Predict : 2017019740001_kwakjuheon , Real : 2017019740001_kwakjuheon
# pre :  0
# Predict : 2017019740001_kwakjuheon , Real : 2017019740001_kwakjuheon
# pre :  46
# Predict : 2017019770016_parkjongae , Real : 2017019740001_kwakjuheon
# pre :  12
# Predict : 2017019740013_kwakyiheon , Real : 2017019740001_kwakjuheon
# pre :  12
# Predict : 2017019740013_kwakyiheon , Real : 2017019740001_kwakjuheon
# pre :  28
# Predict : 2017019740029_limdonggeun , Real : 2017019740029_limdonggeun
# pre :  31
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# pre :  31
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# pre :  46
# Predict : 2017019770016_parkjongae , Real : 2017019770001_kwonyuna
# pre :  46
# Predict : 2017019770016_parkjongae , Real : 2017019770001_kwonyuna
# pre :  31
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# pre :  2
# Predict : 2017019740003_songyejin , Real : 2017019880001_kimsubin
# pre :  71
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# pre :  97
# Predict : 2017019880027_leesol , Real : 2017019880001_kimsubin
# pre :  49
# Predict : 2017019770019_leewooju , Real : 2017019880001_kimsubin
# pre :  80
# Predict : 2017019880010_kimhyorin , Real : 2017019880001_kimsubin
# 0.4375
