2017019880029_kimminji', '2017019880030_hanseungoh', '2017019880031_ahnjiwoo', '2017019880032_seoyeonjoo', '2017019880033_kimnoeun', '2017019880034_leesujung', '2017019880035_songhyunjin', '2017019880036_kimjihye', '2017019880037_jusunghyun', '2017019880038_baejaehong', '2017019880039_seojuyeon', '2017019880040_shinheewook', '2017019880041_kimdaeun', '2017019880042_namyeji', '2017019880043_leegawon', '2017019880044_yoonsuhyun']

# %%
x_list = []
y_list = []

for i in range(0,len(class_names)):
    files=os.listdir(file_path+class_names[i])
    files = [file for file in files if file.endswith(".npy")]

    for j in range(0, len(files)):

        x = np.load(file_path+class_names[i]+"/"+files[j])
        x=x.T
        x_list.append(x)
        y_list.append(i)

# %%
x_train = np.array(x_list)
y_train = np.array(y_list)

print("x_train:", x_train.shape)
print("y_train:", y_train.shape)

from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, stratify=y_train, test_size=0.2, random_state=42)
# Out:
# x_train: (575, 594, 40)
# y_train: (575,)

# %%
print("x_train:", x_train.shape)
print("y_train:", y_train.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val.shape)
# Out:
# x_train: (460, 594, 40)
# y_train: (460,)
# x_val: (115, 594, 40)
# y_val: (115,)

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = tf.keras.utils.to_categorical(y_train)
y_val_encoded = tf.keras.utils.to_categorical(y_val)

# %%
x_train = x_train.reshape(-1, x_train.shape[1], x_train.shape[2], 1)
x_val   = x_val.reshape(-1, x_val.shape[1], x_val.shape[2], 1)

# %%
print("x_train:", x_train.shape)
print("y_train:", y_train_encoded.shape)
print("x_val:", x_val.shape)
print("y_val:", y_val_encoded.shape)
# Out:
# x_train: (460, 594, 40, 1)
# y_train: (460, 115)
# x_val: (115, 594, 40, 1)
# y_val: (115, 115)

# %%
#print(np.min(x_train), np.max(x_train))
#x_train = x_train - np.min(x_train)

#print(np.min(x_train), np.max(x_train))
#x_train = x_train / np.max(x_train)

#print(np.min(x_train), np.max(x_train))

#print(np.min(x_val), np.max(x_val))
#x_val = x_val - np.min(x_val)

#print(np.min(x_val), np.max(x_val))
#x_val = x_val / np.max(x_val)

#print(np.min(x_val), np.max(x_val))

# %%
#from sklearn.preprocessing import MinMaxScaler

#scaler = MinMaxScaler()

#nsamples, nx, ny, nz= x_train.shape
#x_train_nor = scaler.fit_transform(x_train.reshape((nsamples,nx*ny*nz)))
#x_train_nor = x_train_nor.reshape((nsamples,nx,ny,nz))

#nsamples, nx, ny, nz= x_val.shape
#x_val_nor = scaler.transform(x_val.reshape((nsamples,nx*ny*nz)))
#x_val_nor = x_val_nor.reshape((nsamples,nx,ny,nz))

# %%
from tensorflow.keras.layers import Conv2D, Flatten, Dense, BatchNormalization, MaxPool2D
from tensorflow.keras.layers import Dropout, Input, Reshape, Bidirectional, LSTM, Flatten
from tensorflow.keras.models import Model

# %%
input_shape=(x_train.shape[1], x_train.shape[2], 1)

visible = Input(shape=input_shape)

hidden= Conv2D(64, (3, 3), strides=(1, 1), activation='relu', padding='same', name='conv1_1')(visible)
hidden= Conv2D(64, (3, 3), strides=(1, 1), activation='relu', padding='same', name='conv1_2')(hidden)
hidden= MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='pool1', padding='same')(hidden)

hidden= Conv2D(64, (3, 3), strides=(1, 1), activation='relu', padding='same', name='conv2_1')(hidden)
hidden= MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='pool2', padding='same')(hidden)

hidden= Conv2D(128, (3, 3), strides=(1, 1), activation='relu', padding='same', name='conv3_1')(hidden)
hidden= BatchNormalization(name='batchnorm1')(hidden)
hidden= MaxPool2D(pool_size=(2, 2), strides=(1, 2), name='pool3', padding='valid')(hidden)

hidden= Conv2D(128, (2, 2), strides=(1, 1), activation='relu', padding='valid', name='conv4_1')(hidden)
hidden= BatchNormalization(name='batchnorm2')(hidden)
hidden= MaxPool2D(pool_size=(2, 2), strides=(1, 2), name='pool4', padding='valid')(hidden)

#hidden= Conv2D(128, (2, 2), strides=(1, 1), activation='relu', padding='valid', name='conv5_1')(hidden)
#hidden= BatchNormalization(name='batchnorm3')(hidden)
#hidden= MaxPool2D(pool_size=(2, 2), strides=(1, 2), name='pool5', padding='valid')(hidden)

hidden= Conv2D(128, (2, 2), strides=(1, 1), activation='relu', padding='valid', name='conv6_1')(hidden)
#hidden= MaxPool2D(pool_size=(2, 2), strides=(1, 2), name='pool6', padding='valid')(hidden)
hidden = Reshape((hidden.shape[1]*hidden.shape[2],128))(hidden)

hidden= LSTM(64, return_sequences=True)(hidden)
hidden= LSTM(64, return_sequences=True)(hidden)
hidden= Dropout(0.2)(hidden)
hidden= LSTM(32, return_sequences=True)(hidden)
hidden= LSTM(32, return_sequences=True)(hidden)
hidden= Flatten()(hidden)
#hidden = Dense(64, activation='relu')(hidden)

output = Dense(len(class_names), activation="softmax")(hidden)

model = Model(visible, output)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 594, 40, 1)]      0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 594, 40, 64)       640
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 594, 40, 64)       36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 297, 20, 64)       0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 297, 20, 64)       36928
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 149, 10, 64)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 149, 10, 128)      73856
# _________________________________________________________________
# batchnorm1 (BatchNormalizati (None, 149, 10, 128)      512
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 148, 5, 128)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 147, 4, 128)       65664
# _________________________________________________________________
# batchnorm2 (BatchNormalizati (None, 147, 4, 128)       512
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 146, 2, 128)       0
# _________________________________________________________________
# conv6_1 (Conv2D)             (None, 145, 1, 128)       65664
# _________________________________________________________________
# reshape (Reshape)            (None, 145, 128)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 145, 64)           49408
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 145, 64)           33024
# _________________________________________________________________
# dropout (Dropout)            (None, 145, 64)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 145, 32)           12416
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 145, 32)           8320
# _________________________________________________________________
# flatten (Flatten)            (None, 4640)              0
# _________________________________________________________________
# dense (Dense)                (None, 115)               533715
# =================================================================
# Total params: 917,587
# Trainable params: 917,075
# Non-trainable params: 512
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.SGD(lr=0.05, momentum=0.0, decay=0.0, nesterov=False), loss=tf.keras.losses.categorical_crossentropy, metrics=["accuracy"])

# %%
history = model.fit(x_train, y_train_encoded, batch_size=4, epochs=100, verbose=1, validation_data=(x_val, y_val_encoded))
# Out:
# Train on 460 samples, validate on 115 samples
# Epoch 1/100
# 460/460 [==============================] - 8s 17ms/sample - loss: 4.6835 - accuracy: 0.0109 - val_loss: 4.5580 - val_accuracy: 0.0261
# Epoch 2/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 4.1920 - accuracy: 0.0261 - val_loss: 3.9733 - val_accuracy: 0.0609
# Epoch 3/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 3.5393 - accuracy: 0.1174 - val_loss: 5.4835 - val_accuracy: 0.0348
# Epoch 4/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 2.7350 - accuracy: 0.2739 - val_loss: 6.1083 - val_accuracy: 0.0348
# Epoch 5/100
# 460/460 [==============================] - 4s 10ms/sample - loss: 2.0497 - accuracy: 0.4500 - val_loss: 3.2031 - val_accuracy: 0.2261
# Epoch 6/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 1.4178 - accuracy: 0.5804 - val_loss: 3.8130 - val_accuracy: 0.1652
# Epoch 7/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 1.1376 - accuracy: 0.6717 - val_loss: 2.6978 - val_accuracy: 0.4000
# Epoch 8/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.8025 - accuracy: 0.7717 - val_loss: 1.8146 - val_accuracy: 0.5478
# Epoch 9/100
# 460/460 [==============================] - 5s 11ms/sample - loss: 0.4515 - accuracy: 0.8739 - val_loss: 2.2537 - val_accuracy: 0.5217
# Epoch 10/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.3246 - accuracy: 0.9261 - val_loss: 1.8337 - val_accuracy: 0.6000
# Epoch 11/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.2554 - accuracy: 0.9348 - val_loss: 1.9646 - val_accuracy: 0.5826
# Epoch 12/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.1856 - accuracy: 0.9630 - val_loss: 1.6878 - val_accuracy: 0.6174
# Epoch 13/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.1455 - accuracy: 0.9674 - val_loss: 1.5711 - val_accuracy: 0.6435
# Epoch 14/100
# 460/460 [==============================] - 4s 10ms/sample - loss: 0.0865 - accuracy: 0.9870 - val_loss: 1.5224 - val_accuracy: 0.6609
# Epoch 15/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0440 - accuracy: 0.9957 - val_loss: 1.4711 - val_accuracy: 0.6783
# Epoch 16/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0635 - accuracy: 0.9913 - val_loss: 1.4194 - val_accuracy: 0.6609
# Epoch 17/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0634 - accuracy: 0.9913 - val_loss: 1.4258 - val_accuracy: 0.6435
# Epoch 18/100
# 460/460 [==============================] - 5s 11ms/sample - loss: 0.0622 - accuracy: 0.9804 - val_loss: 1.6494 - val_accuracy: 0.6609
# Epoch 19/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0879 - accuracy: 0.9804 - val_loss: 1.4322 - val_accuracy: 0.6522
# Epoch 20/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0293 - accuracy: 0.9957 - val_loss: 1.4471 - val_accuracy: 0.6870
# Epoch 21/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0389 - accuracy: 0.9935 - val_loss: 1.4566 - val_accuracy: 0.7130
# Epoch 22/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.
100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0191 - accuracy: 0.9913 - val_loss: 1.5471 - val_accuracy: 0.6870
# Epoch 73/100
# 460/460 [==============================] - 5s 11ms/sample - loss: 0.0181 - accuracy: 0.9891 - val_loss: 1.5294 - val_accuracy: 0.6696
# Epoch 74/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0172 - accuracy: 0.9913 - val_loss: 1.5652 - val_accuracy: 0.6696
# Epoch 75/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.0192 - accuracy: 0.9870 - val_loss: 1.5873 - val_accuracy: 0.6696
# Epoch 76/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0129 - accuracy: 0.9913 - val_loss: 1.6080 - val_accuracy: 0.6696
# Epoch 77/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.0195 - accuracy: 0.9935 - val_loss: 1.5879 - val_accuracy: 0.6783
# Epoch 78/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0155 - accuracy: 0.9935 - val_loss: 1.5552 - val_accuracy: 0.6696
# Epoch 79/100
# 460/460 [==============================] - 5s 10ms/sample - loss: 0.0174 - accuracy: 0.9891 - val_loss: 1.5744 - val_accuracy: 0.6609
# Epoch 80/100
# 460/460 [==============================] - 4s 10ms/sample - loss: 0.0157 - accuracy: 0.9913 - val_loss: 1.5471 - val_accuracy: 0.6609
# Epoch 81/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0153 - accuracy: 0.9935 - val_loss: 1.5803 - val_accuracy: 0.6696
# Epoch 82/100
# 460/460 [==============================] - 3s 8ms/sample - loss: 0.0153 - accuracy: 0.9935 - val_loss: 1.5996 - val_accuracy: 0.6696
# Epoch 83/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0146 - accuracy: 0.9891 - val_loss: 1.5611 - val_accuracy: 0.6696
# Epoch 84/100
# 460/460 [==============================] - 4s 10ms/sample - loss: 0.0150 - accuracy: 0.9935 - val_loss: 1.5284 - val_accuracy: 0.6696
# Epoch 85/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0145 - accuracy: 0.9935 - val_loss: 1.5348 - val_accuracy: 0.6870
# Epoch 86/100
# 460/460 [==============================] - 4s 10ms/sample - loss: 0.0180 - accuracy: 0.9870 - val_loss: 1.6061 - val_accuracy: 0.6609
# Epoch 87/100
# 460/460 [==============================] - 5s 11ms/sample - loss: 0.0161 - accuracy: 0.9913 - val_loss: 1.5113 - val_accuracy: 0.6696
# Epoch 88/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0138 - accuracy: 0.9935 - val_loss: 1.5148 - val_accuracy: 0.6870
# Epoch 89/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0130 - accuracy: 0.9913 - val_loss: 1.6222 - val_accuracy: 0.6609
# Epoch 90/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0166 - accuracy: 0.9913 - val_loss: 1.7073 - val_accuracy: 0.6609
# Epoch 91/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0227 - accuracy: 0.9870 - val_loss: 1.5937 - val_accuracy: 0.6696
# Epoch 92/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0127 - accuracy: 0.9935 - val_loss: 1.6503 - val_accuracy: 0.6609
# Epoch 93/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0151 - accuracy: 0.9935 - val_loss: 1.7322 - val_accuracy: 0.6609
# Epoch 94/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0162 - accuracy: 0.9891 - val_loss: 1.6180 - val_accuracy: 0.6783
# Epoch 95/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0197 - accuracy: 0.9913 - val_loss: 1.5624 - val_accuracy: 0.6783
# Epoch 96/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0108 - accuracy: 0.9978 - val_loss: 1.6174 - val_accuracy: 0.6609
# Epoch 97/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0173 - accuracy: 0.9935 - val_loss: 1.6796 - val_accuracy: 0.6609
# Epoch 98/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0150 - accuracy: 0.9913 - val_loss: 1.5768 - val_accuracy: 0.6696
# Epoch 99/100
# 460/460 [==============================] - 4s 8ms/sample - loss: 0.0154 - accuracy: 0.9935 - val_loss: 1.5729 - val_accuracy: 0.6696
# Epoch 100/100
# 460/460 [==============================] - 4s 9ms/sample - loss: 0.0157 - accuracy: 0.9913 - val_loss: 1.5434 - val_accuracy: 0.6696

# %%
plt.figure(figsize=(14, 6))
plt.rc('font', size=18)

plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.legend(["train_accuracy", "val_accuracy"])
plt.show()

# %%
from sklearn.metrics import accuracy_score

val_file_path = "../feature/feature_fbank_20s_validation/"
x_validation_list=[]
y_validation_list=[]

val_class_names = os.listdir(val_file_path)
val_class_names.sort()

for i in range(0,len(val_class_names)):
    val_files=os.listdir(val_file_path+val_class_names[i])
    val_files = [file for file in val_files if file.endswith(".npy")]

    for j in range(0, len(val_files)):
        x = np.load(val_file_path+val_class_names[i]+"/"+val_files[j])
        x=x.T
        x_validation_list.append(x)
        y_validation_list.append(i)


x_validation = np.array(x_validation_list)
y_validation = np.array(y_validation_list)
y_validation_encoded = tf.keras.utils.to_categorical(y_validation)

x_validation = x_validation.reshape(-1, x_validation.shape[1], x_validation.shape[2], 1)


#x_validation = x_validation - np.min(x_validation)
#x_validation = x_validation / np.max(x_validation)
real =[]
pred_out_idex=[]

for k in range(0, len(x_validation)):
    
    kt = x_validation[k].reshape(-1, x_validation.shape[1], x_validation.shape[2], 1)
    
    #nsamples, nx, ny,nz = kt.shape
    #kt = scaler.transform(kt.reshape((nsamples,nx*ny*nz)))
    #kt = kt.reshape((nsamples,nx,ny,nz))
    
    predictions_single = model.predict(kt)
    print("Predict :",class_names[np.argmax(predictions_single)],", Real :",val_class_names[y_validation[k]])
    real.append(class_names.index(val_class_names[y_validation[k]]))
    pred_out_idex.append(np.argmax(predictions_single))
    
# get the accuracy
print (accuracy_score(real, pred_out_idex))

#batch=4, epoch=50 0.5625 val_accuracy: 0.6783
#batch=16, epoch=50 0.75 val_accuracy: 0.8000
#batch=32, epoch=50 0.5625 val_accuracy: 0.7913
#batch=8, epoch=100 0.75 val_accuracy: 0.7130
#batch=16, epoch=100 0.6875 val_accuracy: 0.8000
# Out:
# Predict : 2017019880038_baejaehong , Real : 2017019740001_kwakjuheon
# Predict : 2017019740001_kwakjuheon , Real : 2017019740001_kwakjuheon
# Predict : 2017019770033_kwonsundo , Real : 2017019740001_kwakjuheon
# Predict : 2017019880038_baejaehong , Real : 2017019740001_kwakjuheon
# Predict : 2017019740001_kwakjuheon , Real : 2017019740001_kwakjuheon
# Predict : 2017019770039_ohjiwon , Real : 2017019740001_kwakjuheon
# Predict : 2017019740029_limdonggeun , Real : 2017019740029_limdonggeun
# Predict : 2017019880038_baejaehong , Real : 2017019770001_kwonyuna
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# Predict : 2017019880038_baejaehong , Real : 2017019770001_kwonyuna
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# Predict : 2017019880038_baejaehong , Real : 2017019770001_kwonyuna
# Predict : 2017019880004_myeongjaewon , Real : 2017019880001_kimsubin
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# Predict : 2017019880001_kimsubin , Real : 2017019880001_kimsubin
# 0.5789473684210527

# %%
real =[]
pred_out_idex=[]

for k in range(0, len(x_val)):
    
    kt = x_val[k].reshape(-1, x_val.shape[1], x_val.shape[2], 1)
    
    #nsamples, nx, ny,nz = kt.shape
    #kt = scaler.transform(kt.reshape((nsamples,nx*ny*nz)))
    #kt = kt.reshape((nsamples,nx,ny,nz))
    
    predictions_single = model.predict(kt)
    print("Predict :",class_names[np.argmax(predictions_single)],", Real :",class_names[y_val[k]])
    real.append(class_names.index(class_names[y_val[k]]))
    pred_out_idex.append(np.argmax(predictions_single))
    
# get the accuracy
print (accuracy_score(real, pred_out_idex))
# Out:
# Predict : 2017019770038_kanghyeyun , Real : 2017019880013_kotaewan
# Predict : 2017019770031_kwonnahui , Real : 2017019770031_kwonnahui
# Predict : 2017019880021_kimjuyeong , Real : 2017019880021_kimjuyeong
# Predict : 2017019880039_seojuyeon , Real : 2017019880039_seojuyeon
# Predict : 2017019880032_seoyeonjoo , Real : 2017019880032_seoyeonjoo
# Predict : 2017019880017_sungsoohyun , Real : 2017019880011_kimjihyun
# Predict : 2017019770015_parkdayeung , Real : 2017019770015_parkdayeung
# Predict : 2017019740026_parkyeongseon , Real : 2017019740027_kwaksangpil
# Predict : 2017019770035_leehyojin , Real : 2017019770035_leehyojin
# Predict : 2017019740016_kangyeseo , Real : 2017019740016_kangyeseo
# Predict : 2017019880003_kimminji , Real : 2017019770023_kimsoyung
# Predict : 2017019880038_baejaehong , Real : 2017019740005_moonyeonwoo
# Predict : 2017019770038_kanghyeyun , Real : 2017019740012_chaeminjoon
# Predict : 2017019770038_kanghyeyun , Real : 2017019770038_kanghyeyun
# Predict : 2017019880023_yoohaekyung , Real : 2017019880033_kimnoeun
# Predict : 2017019770009_yuminji , Real : 2017019770036_yuminji
# Predict : 2017019880028_kimsunghan , Real : 2017019880038_baejaehong
# Predict : 2017019740029_limdonggeun , Real : 2017019740029_limdonggeun
# Predict : 2017019770022_heojaemin , Real : 2017019770022_heojaemin
# Predict : 2017019880037_jusunghyun , Real : 2017019880037_jusunghyun
# Predict : 2017019880025_yoojungkyun , Real : 2017019880025_yoojungkyun
# Predict : 2017019770037_jeonghojun , Real : 2017019770037_jeonghojun
# Predict : 2017019770033_kwonsundo , Real : 2017019770039_ohjiwon
# Predict : 2017019880020_yoonhyeeun , Real : 2017019880020_yoonhyeeun
# Predict : 2017019770001_kwonyuna , Real : 2017019770001_kwonyuna
# Predict : 2017019880036_kimjihye , Real : 2017019880030_hanseungoh
# Predict : 2017019770012_ladakyeong , Real : 2017019770012_ladakyeong
# Predict : 2017019740010_kwakmirae , Real : 2017019880005_kimjihyeon
