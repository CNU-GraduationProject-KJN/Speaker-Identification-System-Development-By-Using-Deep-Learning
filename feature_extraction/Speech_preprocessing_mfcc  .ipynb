# %%
from time import sleep

import pickle
import shutil
import numpy as np
import librosa
import librosa.display
import os
import matplotlib.pyplot as plt

from matplotlib import cm # for color map
from python_speech_features import logfbank, fbank
from scipy.fftpack import dct

import speech_recognition as speech_r
import scipy.signal as signal
from pydub import AudioSegment

from silence_remover.silence_detector import SilenceDetector
from silence_remover.filter_generator import FilterGenerator
from silence_remover.media_editor import MediaEditor

# %% [markdown]
# Checking librosa version and speech_recognition version

# %%
print("librosa version : ",librosa.__version__)
print("speech_recognition version : ", speech_r.__version__)
save_path = "../test_train_data/"
# Out:
# librosa version :  0.7.2
# speech_recognition version :  3.8.1

# %% [markdown]
# #### Select WAV file

# %%
user_list = os.listdir(save_path)
user_list.sort()
r = speech_r.Recognizer() 

print("User List :")
testInt = 0
for i, item in zip(range(len(user_list)), user_list):
    print('[{:d}] '.format(i)+item)

    file_list = os.listdir(save_path + str(user_list[i]+"/"))
    file_list.sort()

    if os.path.exists("../feature/feature_mfcc/"+str(user_list[i]+"/")):
        shutil.rmtree("../feature/feature_mfcc/"+str(user_list[i]+"/"))
    for j, item in zip(range(len(file_list)), file_list):
        testInt = testInt+1
        final_file_name = save_path + str(user_list[i]) +"/"+ str(file_list[j])
        print(final_file_name)
        
        if not final_file_name.endswith(".wav") :
            
            (path, file_extension) = os.path.splitext(final_file_name)
            file_extension_final = file_extension.replace('.', '')

            track = AudioSegment.from_file(final_file_name,file_extension_final)
            wav_filename = final_file_name.replace(file_extension_final, 'wav')

            wav_path = wav_filename
            print('CONVERTING: ' + str(final_file_name))
            file_handle = track.export(wav_path, format='wav')
            os.remove(final_file_name)
        else :
            wav_path = final_file_name
            
        hop_length = 512
        n_mels = 40
        n_fft = 512
        sr = 16000

        jackhammer = speech_r.AudioFile(wav_path)

        with jackhammer as source:
            r.adjust_for_ambient_noise(source)
            audio = r.record(source)
            
            temp_file = wav_path.replace(".wav", "Temp.wav")
            fw = open(temp_file, "wb")
            fw.write(audio.get_wav_data())
            fw.close()
            
            y, sr = librosa.load(temp_file, sr=16000, mono=True, duration=15)
            y = y[0:int(15.0 * sr)]
            stft = librosa.stft(y=y, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hamm',
             center=True, dtype=np.complex64, pad_mode='reflect')
            abs_STFT = np.abs(stft)
    
            mel = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels)
            mel /= np.max(mel, axis=-1)[:, None]
            mel_S = np.dot(mel, abs_STFT)
            mel_spec_test = 20 * np.log10(np.maximum(mel_S, 1e-5))
    
            num_ceps = 12
            cep_lifter = 22
    
            mfcc = dct(mel_spec_test.T, type=2 ,axis=1, norm='ortho')[:, 1 : (num_ceps + 1)] 
            (nframes, ncoeff) = mfcc.shape

            n = np.arange(ncoeff)
    
    
            # to de-emphasize higher MFCCs (for Noise)
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc_lifted = mfcc * lift  
            mfcc_normalized = mfcc_lifted -(np.mean(mfcc_lifted, axis=0) + 1e-8)
    
            feature_save_path = "../feature/feature_mfcc/"+str(user_list[i]+"/")


            if not os.path.exists(feature_save_path):
                os.makedirs(feature_save_path)
                feature_result_name = str(user_list[i]) +"_"+str(0)
            else :
                feature_files = os.listdir(feature_save_path)
                feature_files = [file for file in feature_files if file.endswith(".npy")]
                feature_result_name = str(user_list[i]) +"_"+str(len(feature_files))
        
            if os.path.exists(feature_save_path + feature_result_name+".txt"):
                os.remove(feature_save_path + feature_result_name+".txt")
                os.remove(feature_save_path + feature_result_name+".npy")
                
            f= open(feature_save_path + feature_result_name+".txt", "w")

            feature_description = "sr=%d\n" % sr
            feature_description += "hop_length=%d\n" % hop_length
            feature_description += "n_fft=%d\n" % n_fft
            feature_description += "n_mels=%d\n" % n_mels
            feature_description += "time=%d\n" % int(len(y)/sr)

            f.write(feature_description)
            f.close()

            print(feature_result_name + "' File Write Finish !")
            np.save(feature_save_path + feature_result_name, mfcc_normalized) # x_save.npy
            print(" Saved File Name : "+feature_result_name)

            os.remove(temp_file)
            sleep(1)
print(testInt)
# Out:
# User List :
# [0] 2017019740001_kwakjuheon
# ../test_train_data/2017019740001_kwakjuheon/1.wav
# 2017019740001_kwakjuheon_0' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_0
# ../test_train_data/2017019740001_kwakjuheon/2.wav
# 2017019740001_kwakjuheon_1' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_1
# ../test_train_data/2017019740001_kwakjuheon/3.wav
# 2017019740001_kwakjuheon_2' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_2
# ../test_train_data/2017019740001_kwakjuheon/4.wav
# 2017019740001_kwakjuheon_3' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_3
# ../test_train_data/2017019740001_kwakjuheon/5.wav
# 2017019740001_kwakjuheon_4' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_4
# [1] 2017019740002_kimjiho
# ../test_train_data/2017019740002_kimjiho/1.wav
# 2017019740002_kimjiho_0' File Write Finish !
#  Saved File Name : 2017019740002_kimjiho_0
# ../test_train_data/2017019740002_kimjiho/2.wav
# 2017019740002_kimjiho_1' File Write Finish !
#  Saved File Name : 2017019740002_kimjiho_1
# ../test_train_data/2017019740002_kimjiho/3.wav
# 2017019740002_kimjiho_2' File Write Finish !
#  Saved File Name : 2017019740002_kimjiho_2
# ../test_train_data/2017019740002_kimjiho/4.wav
# 2017019740002_kimjiho_3' File Write Finish !
#  Saved File Name : 2017019740002_kimjiho_3
# ../test_train_data/2017019740002_kimjiho/5.wav
# 2017019740002_kimjiho_4' File Write Finish !
#  Saved File Name : 2017019740002_kimjiho_4
# [2] 2017019740003_songyejin
# ../test_train_data/2017019740003_songyejin/1.wav
# 2017019740003_songyejin_0' File Write Finish !
#  Saved File Name : 2017019740003_songyejin_0
# ../test_train_data/2017019740003_songyejin/2.wav
# 2017019740003_songyejin_1' File Write Finish !
#  Saved File Name : 2017019740003_songyejin_1
#  Saved File Name : 2017019740014_leesumin_2
# ../test_train_data/2017019740014_leesumin/4.wav
# 2017019740014_leesumin_3' File Write Finish !
#  Saved File Name : 2017019740014_leesumin_3
# ../test_train_data/2017019740014_leesumin/5.wav
# 2017019740014_leesumin_4' File Write Finish !
#  Saved File Name : 2017019740014_leesumin_4
# [14] 2017019740015_choihayoung
# ../test_train_data/2017019740015_choihayoung/1.wav
# 2017019740015_choihayoung_0' File Write Finish !
#  Saved File Name : 2017019740015_choihayoung_0
# ../test_train_data/2017019740015_choihayoung/2.wav
# 2017019740015_choihayoung_1' File Write Finish !
#  Saved File Name : 2017019740015_choihayoung_1
# ../test_train_data/2017019740015_choihayoung/3.wav
# 2017019740015_choihayoung_2' File Write Finish !
#  Saved File Name : 2017019740015_choihayoung_2
# ../test_train_data/2017019740015_choihayoung/4.wav
# 2017019740015_choihayoung_3' File Write Finish !
#  Saved File Name : 2017019740015_choihayoung_3
# ../test_train_data/2017019740015_choihayoung/5.wav
# 2017019740015_choihayoung_4' File Write Finish !
#  Saved File Name : 2017019740015_choihayoung_4
# [15] 2017019740016_kangyeseo
# ../test_train_data/2017019740016_kangyeseo/1.wav
# 2017019740016_kangyeseo_0' File Write Finish !
#  Saved File Name : 2017019740016_kangyeseo_0
# ../test_train_data/2017019740016_kangyeseo/2.wav
# 2017019740016_kangyeseo_1' File Write Finish !
#  Saved File Name : 2017019740016_kangyeseo_1
# ../test_train_data/2017019740016_kangyeseo/3.wav
# 2017019740016_kangyeseo_2' File Write Finish !
#  Saved File Name : 2017019740016_kangyeseo_2
# ../test_train_data/2017019740016_kangyeseo/4.wav
# 2017019740016_kangyeseo_3' File Write Finish !
#  Saved File Name : 2017019740016_kangyeseo_3
# ../test_train_data/2017019740016_kangyeseo/5.wav
# 2017019740016_kangyeseo_4' File Write Finish !
#  Saved File Name : 2017019740016_kangyeseo_4
# [16] 2017019740017_kwakmihyang
# ../test_train_data/2017019740017_kwakmihyang/1.wav
# 2017019740017_kwakmihyang_0' File Write Finish !
#  Saved File Name : 2017019740017_kwakmihyang_0
# ../test_train_data/2017019740017_kwakmihyang/2.wav
# 2017019740017_kwakmihyang_1' File Write Finish !
#  Saved File Name : 2017019740017_kwakmihyang_1
# ../test_train_data/2017019740017_kwakmihyang/3.wav
# 2017019740017_kwakmihyang_2' File Write Finish !
#  Saved File Name : 2017019740017_kwakmihyang_2
# ../test_train_data/2017019740017_kwakmihyang/4.wav
# 2017019740017_kwakmihyang_3' File Write Finish !
#  Saved File Name : 2017019740017_kwakmihyang_3
# ../test_train_data/2017019740017_kwakmihyang/5.wav
# 2017019740017_kwakmihyang_4' File Write Finish !
#  Saved File Name : 2017019740017_kwakmihyang_4
# [17] 2017019740018_eundano
# ../test_train_data/2017019740018_eundano/1.wav
# 2017019740018_eundano_0' File Write Finish !
#  Saved File Name : 2017019740018_eundano_0
# ../test_train_data/2017019740018_eundano/2.wav
# 2017019740018_eundano_1' File Write Finish !
#  Saved File Name : 2017019740018_eundano_1
# ../test_train_data/2017019770022_heojaemin/3.wav
# 2017019770022_heojaemin_2' File Write Finish !
#  Saved File Name : 2017019770022_heojaemin_2
# ../test_train_data/2017019770022_heojaemin/4.wav
# 2017019770022_heojaemin_3' File Write Finish !
#  Saved File Name : 2017019770022_heojaemin_3
# ../test_train_data/2017019770022_heojaemin/5.wav
# 2017019770022_heojaemin_4' File Write Finish !
#  Saved File Name : 2017019770022_heojaemin_4
# [41] 2017019770023_kimsoyung
# ../test_train_data/2017019770023_kimsoyung/1.wav
# 2017019770023_kimsoyung_0' File Write Finish !
#  Saved File Name : 2017019770023_kimsoyung_0
# ../test_train_data/2017019770023_kimsoyung/2.wav
# 2017019770023_kimsoyung_1' File Write Finish !
#  Saved File Name : 2017019770023_kimsoyung_1
# ../test_train_data/2017019770023_kimsoyung/3.wav
# 2017019770023_kimsoyung_2' File Write Finish !
#  Saved File Name : 2017019770023_kimsoyung_2
# ../test_train_data/2017019770023_kimsoyung/4.wav
# 2017019770023_kimsoyung_3' File Write Finish !
#  Saved File Name : 2017019770023_kimsoyung_3
# ../test_train_data/2017019770023_kimsoyung/5.wav
# 2017019770023_kimsoyung_4' File Write Finish !
#  Saved File Name : 2017019770023_kimsoyung_4
# [42] 2017019770024_chuminha
# ../test_train_data/2017019770024_chuminha/1.wav
# 2017019770024_chuminha_0' File Write Finish !
#  Saved File Name : 2017019770024_chuminha_0
# ../test_train_data/2017019770024_chuminha/2.wav
# 2017019770024_chuminha_1' File Write Finish !
#  Saved File Name : 2017019770024_chuminha_1
# ../test_train_data/2017019770024_chuminha/3.wav
# 2017019770024_chuminha_2' File Write Finish !
#  Saved File Name : 2017019770024_chuminha_2
# ../test_train_data/2017019770024_chuminha/4.wav
# 2017019770024_chuminha_3' File Write Finish !
#  Saved File Name : 2017019770024_chuminha_3
# ../test_train_data/2017019770024_chuminha/5.wav
# 2017019770024_chuminha_4' File Write Finish !
#  Saved File Name : 2017019770024_chuminha_4
# [43] 2017019770025_kimhyeonsu
# ../test_train_data/2017019770025_kimhyeonsu/1.wav
# 2017019770025_kimhyeonsu_0' File Write Finish !
#  Saved File Name : 2017019770025_kimhyeonsu_0
# ../test_train_data/2017019770025_kimhyeonsu/2.wav
# 2017019770025_kimhyeonsu_1' File Write Finish !
#  Saved File Name : 2017019770025_kimhyeonsu_1
# ../test_train_data/2017019770025_kimhyeonsu/3.wav
# 2017019770025_kimhyeonsu_2' File Write Finish !
#  Saved File Name : 2017019770025_kimhyeonsu_2
# ../test_train_data/2017019770025_kimhyeonsu/4.wav
# 2017019770025_kimhyeonsu_3' File Write Finish !
#  Saved File Name : 2017019770025_kimhyeonsu_3
# ../test_train_data/2017019770025_kimhyeonsu/5.wav
# 2017019770025_kimhyeonsu_4' File Write Finish !
#  Saved File Name : 2017019770025_kimhyeonsu_4
# [44] 2017019770026_chaesonghwa
# ../test_train_data/2017019770026_chaesonghwa/1.wav
# 2017019770026_chaesonghwa_0' File Write Finish !
# ../test_train_data/2017019880003_kimminji/5.wav
# 2017019880003_kimminji_4' File Write Finish !
#  Saved File Name : 2017019880003_kimminji_4
# [52] 2017019880004_myeongjaewon
# ../test_train_data/2017019880004_myeongjaewon/1.wav
# 2017019880004_myeongjaewon_0' File Write Finish !
#  Saved File Name : 2017019880004_myeongjaewon_0
# ../test_train_data/2017019880004_myeongjaewon/2.wav
# 2017019880004_myeongjaewon_1' File Write Finish !
#  Saved File Name : 2017019880004_myeongjaewon_1
# ../test_train_data/2017019880004_myeongjaewon/3.wav
# 2017019880004_myeongjaewon_2' File Write Finish !
#  Saved File Name : 2017019880004_myeongjaewon_2
# ../test_train_data/2017019880004_myeongjaewon/4.wav
# 2017019880004_myeongjaewon_3' File Write Finish !
#  Saved File Name : 2017019880004_myeongjaewon_3
# ../test_train_data/2017019880004_myeongjaewon/5.wav
# 2017019880004_myeongjaewon_4' File Write Finish !
#  Saved File Name : 2017019880004_myeongjaewon_4
# [53] 2017019880005_kimjihyeon
# ../test_train_data/2017019880005_kimjihyeon/1.wav
# 2017019880005_kimjihyeon_0' File Write Finish !
#  Saved File Name : 2017019880005_kimjihyeon_0
# ../test_train_data/2017019880005_kimjihyeon/2.wav
# 2017019880005_kimjihyeon_1' File Write Finish !
#  Saved File Name : 2017019880005_kimjihyeon_1
# ../test_train_data/2017019880005_kimjihyeon/3.wav
# 2017019880005_kimjihyeon_2' File Write Finish !
#  Saved File Name : 2017019880005_kimjihyeon_2
# ../test_train_data/2017019880005_kimjihyeon/4.wav
# 2017019880005_kimjihyeon_3' File Write Finish !
#  Saved File Name : 2017019880005_kimjihyeon_3
# ../test_train_data/2017019880005_kimjihyeon/5.wav
# 2017019880005_kimjihyeon_4' File Write Finish !
#  Saved File Name : 2017019880005_kimjihyeon_4
# 270

# %%
save_path = "../test_val_data/"
user_list = os.listdir(save_path)
user_list.sort()
r = speech_r.Recognizer() 

print("User List :")
testInt = 0
for i, item in zip(range(len(user_list)), user_list):
    print('[{:d}] '.format(i)+item)

    file_list = os.listdir(save_path + str(user_list[i]+"/"))
    file_list.sort()

    
    if os.path.exists("../feature/feature_mfcc_validation/"+str(user_list[i]+"/")):
        shutil.rmtree("../feature/feature_mfcc_validation/"+str(user_list[i]+"/"))
    for j, item in zip(range(len(file_list)), file_list):
        testInt = testInt+1
        final_file_name = save_path + str(user_list[i]) +"/"+ str(file_list[j])
        print(final_file_name)
        if not final_file_name.endswith(".wav") :
            
            (path, file_extension) = os.path.splitext(final_file_name)
            file_extension_final = file_extension.replace('.', '')

            track = AudioSegment.from_file(final_file_name,file_extension_final)
            wav_filename = final_file_name.replace(file_extension_final, 'wav')

            wav_path = wav_filename
            print('CONVERTING: ' + str(final_file_name))
            file_handle = track.export(wav_path, format='wav')
            os.remove(final_file_name)
        else :
            wav_path = final_file_name
            
        hop_length = 512
        n_mels = 40
        n_fft = 512
        sr = 16000

        jackhammer = speech_r.AudioFile(wav_path)

        with jackhammer as source:
            r.adjust_for_ambient_noise(source)
            audio = r.record(source)
            
            temp_file = wav_path.replace(".wav", "Temp.wav")
            fw = open(temp_file, "wb")
            fw.write(audio.get_wav_data())
            fw.close()
            
            y, sr = librosa.load(temp_file, sr=16000, mono=True, duration=15)
            y = y[0:int(15.0 * sr)]
            stft = librosa.stft(y=y, n_fft=n_fft, hop_length=hop_length, win_length=None, window='hamm',
             center=True, dtype=np.complex64, pad_mode='reflect')
            abs_STFT = np.abs(stft)
    
            mel = librosa.filters.mel(sr=sr, n_fft=n_fft, n_mels=n_mels)
            mel /= np.max(mel, axis=-1)[:, None]
            mel_S = np.dot(mel, abs_STFT)
            mel_spec_test = 20 * np.log10(np.maximum(mel_S, 1e-5))
    
            num_ceps = 12
            cep_lifter = 22
    
            mfcc = dct(mel_spec_test.T, type=2 ,axis=1, norm='ortho')[:, 1 : (num_ceps + 1)] 
            (nframes, ncoeff) = mfcc.shape

            n = np.arange(ncoeff)
    
    
            # to de-emphasize higher MFCCs (for Noise)
            lift = 1 + (cep_lifter / 2) * np.sin(np.pi * n / cep_lifter)
            mfcc_lifted = mfcc * lift  
            mfcc_normalized = mfcc_lifted -(np.mean(mfcc_lifted, axis=0) + 1e-8)
    
            feature_save_path = "../feature/feature_mfcc_validation/"+str(user_list[i]+"/")


            if not os.path.exists(feature_save_path):
                os.makedirs(feature_save_path)
                feature_result_name = str(user_list[i]) +"_"+str(0)
            else :
                feature_files = os.listdir(feature_save_path)
                feature_files = [file for file in feature_files if file.endswith(".npy")]
                feature_result_name = str(user_list[i]) +"_"+str(len(feature_files))
        
            if os.path.exists(feature_save_path + feature_result_name+".txt"):
                os.remove(feature_save_path + feature_result_name+".txt")
                os.remove(feature_save_path + feature_result_name+".npy")
                
            f= open(feature_save_path + feature_result_name+".txt", "w")

            feature_description = "sr=%d\n" % sr
            feature_description += "hop_length=%d\n" % hop_length
            feature_description += "n_fft=%d\n" % n_fft
            feature_description += "n_mels=%d\n" % n_mels
            feature_description += "time=%d\n" % int(len(y)/sr)

            f.write(feature_description)
            f.close()

            print(feature_result_name + "' File Write Finish !")
            np.save(feature_save_path + feature_result_name, mfcc_normalized) # x_save.npy
            print(" Saved File Name : "+feature_result_name)

            os.remove(temp_file)
            sleep(1)
print(testInt)
# Out:
# User List :
# [0] 2017019740001_kwakjuheon
# ../test_val_data/2017019740001_kwakjuheon/1.wav
# 2017019740001_kwakjuheon_0' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_0
# ../test_val_data/2017019740001_kwakjuheon/2.wav
# 2017019740001_kwakjuheon_1' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_1
# ../test_val_data/2017019740001_kwakjuheon/3.wav
# 2017019740001_kwakjuheon_2' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_2
# ../test_val_data/2017019740001_kwakjuheon/4.wav
# 2017019740001_kwakjuheon_3' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_3
# ../test_val_data/2017019740001_kwakjuheon/5.wav
# 2017019740001_kwakjuheon_4' File Write Finish !
#  Saved File Name : 2017019740001_kwakjuheon_4
# [1] 2017019880001_kimsubin
# ../test_val_data/2017019880001_kimsubin/1.wav
# 2017019880001_kimsubin_0' File Write Finish !
#  Saved File Name : 2017019880001_kimsubin_0
# ../test_val_data/2017019880001_kimsubin/2.wav
# 2017019880001_kimsubin_1' File Write Finish !
#  Saved File Name : 2017019880001_kimsubin_1
# ../test_val_data/2017019880001_kimsubin/3.wav
# 2017019880001_kimsubin_2' File Write Finish !
#  Saved File Name : 2017019880001_kimsubin_2
# ../test_val_data/2017019880001_kimsubin/4.wav
# 2017019880001_kimsubin_3' File Write Finish !
#  Saved File Name : 2017019880001_kimsubin_3
# ../test_val_data/2017019880001_kimsubin/5.wav
# 2017019880001_kimsubin_4' File Write Finish !
#  Saved File Name : 2017019880001_kimsubin_4
# 10

# %%
user_feature_list = os.listdir("../feature/feature_mfcc/")
user_feature_list.sort()

print("User List :")
for i, item in zip(range(len(user_feature_list)), user_feature_list):
    print('[{:d}] '.format(i)+item)

selUserNum_forFeature = int(input("\n유저 번호를 선택하세요 : "))

feature_to_file_list = os.listdir("../feature/feature_mfcc/" + str(user_feature_list[selUserNum_forFeature]+"/"))
feature_npy_file_list = [file for file in feature_to_file_list if file.endswith(".npy")]
feature_npy_file_list.sort()

print("\nFile List : ")
for i, item in zip(range(len(feature_npy_file_list)), feature_npy_file_list):
    print('[{:d}] '.format(i)+item)
    
selFileNum_forFeature = int(input("\n파일 번호를 선택하세요 : "))

final_feat_name = "../feature/feature_mfcc/" + str(user_feature_list[selUserNum_forFeature]) +"/"+ str(feature_npy_file_list[selFileNum_forFeature])
feature_load = np.load(final_feat_name)

feature_txt_file_list = [file for file in feature_to_file_list if file.endswith(".txt")]
feat_descriptions = "../feature/feature_mfcc/" + str(user_feature_list[selUserNum_forFeature]) +"/"+ str(feature_txt_file_list[selFileNum_forFeature])

print(feat_descriptions+" 파일을 불러옵니다. \n")
f_d = open(feat_descriptions, 'r')
line = f_d.readline()
loaded_sr = int(line.split('=')[1].rstrip('\n'))
line = f_d.readline()
loaded_hop_length =int(line.split('=')[1].rstrip('\n'))
line = f_d.readline()
loaded_n_fft = int(line.split('=')[1].rstrip('\n'))
line = f_d.readline()
loaded_n_mels = int(line.split('=')[1].rstrip('\n'))
line = f_d.readline()
loaded_time = int(line.split('=')[1].rstrip('\n'))

print(loaded_sr, loaded_hop_length, loaded_n_fft, loaded_n_mels, loaded_time)

# %% [markdown]
# ### Visualize Loaded Feature

# %%
plt.figure(figsize=(14, 6))
plt.rc('font', size=18)

plt.title("Loaded Feature Spectogram")
librosa.display.specshow(feature_load.T, sr=loaded_sr, hop_length=loaded_hop_length, x_axis='s', cmap=cm.jet)
# plt.colorbar()
plt.grid('on')
plt.ylabel('MFCC Coefficients')
plt.xticks(np.arange(0, loaded_time+1, step=1), ["{:d}".format(x) for x in np.arange(0, loaded_time+1, step=1)], 
           fontsize=18)

plt.show()
